# %% [markdown]
# <a href="https://colab.research.google.com/github/juansvas/testing_repo/blob/master/Practice_Exploration_Diamonds_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3cf44343-e4ed-4690-a46d-14f4c9bbc6c8" name="files[]" multiple disabled />
#      <output id="result-3cf44343-e4ed-4690-a46d-14f4c9bbc6c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diamonds.csv to diamonds.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['diamonds.csv']))

# %%
df.head()
df.drop(labels="Unnamed: 0", axis=1)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
# Unnamed: 0    53940 non-null int64
# carat         53940 non-null float64
# cut           53940 non-null object
# color         53940 non-null object
# clarity       53940 non-null object
# depth         53940 non-null float64
# table         53940 non-null float64
# price         53940 non-null int64
# x             53940 non-null float64
# y             53940 non-null float64
# z             53940 non-null float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df['clarity'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        SI2
# 1        SI1
# 2        VS1
# 3        VS2
# 4        SI2
#         ...
# 53935    SI1
# 53936    SI1
# 53937    SI1
# 53938    SI2
# 53939    SI2
# Name: clarity, Length: 53940, dtype: object>

# %%
df.describe()
# Out:
#          Unnamed: 0         carat  ...             y             z
# count  53940.000000  53940.000000  ...  53940.000000  53940.000000
# mean   26970.500000      0.797940  ...      5.734526      3.538734
# std    15571.281097      0.474011  ...      1.142135      0.705699
# min        1.000000      0.200000  ...      0.000000      0.000000
# 25%    13485.750000      0.400000  ...      4.720000      2.910000
# 50%    26970.500000      0.700000  ...      5.710000      3.530000
# 75%    40455.250000      1.040000  ...      6.540000      4.040000
# max    53940.000000      5.010000  ...     58.900000     31.800000
#
# [8 rows x 8 columns]

# %%
df.hist(bins=50, figsize=(20,20))
plt.show()

# %%
cor = df.corr()
plt.figure(figsize = (15,15))
sns.heatmap(cor, annot=True)

# %%
scatter = sns.scatterplot(x=df['carat'], y=df['price'], data=df, palette='cmap')
