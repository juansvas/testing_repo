# %%
# Calculating Return on Equity with Python
# https://towardsdatascience.com/calculating-return-on-equity-with-python-1ea583cd53bd

# %%
# Set up
import requests as r

# Create data for given stock
stock = 't'
income_statement = r.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{stock}?period=quarter")
data = income_statement.json()
data
# Out:
# {'financials': [{'Consolidated Income': '3700000000.0',
#    'Cost of Revenue': '27103000000.0',
#    'Dividend per Share': '0.508946865182',
#    'EBIT': '7901000000.0',
#    'EBIT Margin': '0.177200143536',
#    'EBITDA': '16710000000.0',
#    'EBITDA Margin': '0.374764510631',
#    'EPS': '0.51',
#    'EPS Diluted': '0.51',
#    'Earnings Before Tax Margin': '0.103996591011',
#    'Earnings before Tax': '4637000000.0',
#    'Free Cash Flow margin': '0.140127388535',
#    'Gross Margin': '0.392145868844',
#    'Gross Profit': '17485000000.0',
#    'Income Tax Expense': '937000000.0',
#    'Interest Expense': '937000000.0',
#    'Net Income': '3700000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3700000000.0',
#    'Net Profit Margin': '0.0829819682426',
#    'Operating Expenses': '9584000000.0',
#    'Operating Income': '7901000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0829819682426',
#    'R&D Expenses': '0.0',
#    'Revenue': '44588000000.0',
#    'Revenue Growth': '-0.00820784305002558',
#    'SG&A Expense': '19168000000.0',
#    'Weighted Average Shs Out': '7321000000.0',
#    'Weighted Average Shs Out (Dil)': '7321000000.0',
#    'date': '2019-09-30'},
#   {'Consolidated Income': '3713000000.0',
#    'Cost of Revenue': '27613000000.0',
#    'Dividend per Share': '0.508608909538',
#    'EBIT': '7500000000.0',
#    'EBIT Margin': '0.166826078253',
#    'EBITDA': '17303000000.0',
#    'EBITDA Margin': '0.384878884267',
#    'EPS': '0.5',
#    'EPS Diluted': '0.5',
#    'Earnings Before Tax Margin': '0.107035611807',
#    'Earnings before Tax': '4812000000.0',
#    'Free Cash Flow margin': '0.19714393754',
#    'Gross Margin': '0.385790866828',
#    'Gross Profit': '17344000000.0',
#    'Income Tax Expense': '1099000000.0',
#    'Interest Expense': '1099000000.0',
#    'Net Income': '3713000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3713000000.0',
#    'Net Profit Margin': '0.0825900304736',
#    'Operating Expenses': '9844000000.0',
#    'Operating Income': '7500000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0825900304736',
#    'R&D Expenses': '0.0',
#    'Revenue': '44957000000.0',
#    'Revenue Growth': '0.00290003792357285',
#    'SG&A Expense': '19688000000.0',
#    'Weighted Average Shs Out': '7318000000.0',
#    'Weighted Average Shs Out (Dil)': '7318000000.0',
#    'date': '2019-06-30'},
#   {'Consolidated Income': '4096000000.0',
#    'Cost of Revenue': '27945000000.0',
#    'Dividend per Share': '0.507862710242',
#    'EBIT': '7233000000.0',
#    'EBIT Margin': '0.161353648471',
#    'EBITDA': '16936000000.0',
#    'EBITDA Margin': '0.377808017489',
#    'EPS': '0.56',
#    'EPS Diluted': '0.56',
#    'Earnings Before Tax Margin': '0.114194570237',
#    'Earnings before Tax': '5119000000.0',
#    'Free Cash Flow margin': '0.132308653267',
#    'Gross Margin': '0.376603386352',
#    'Gross Profit': '16882000000.0',
#    'Income Tax Expense': '1023000000.0',
#    'Interest Expense': '1023000000.0',
#    'Net Income': '4096000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '4096000000.0',
#    'Net Profit Margin': '0.0913735025766',
#    'Operating Expenses': '9649000000.0',
#    'Operating Income': '7233000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0913735025766',
#    'R&D Expenses': '0.0',
#    'Revenue': '44827000000.0',
#    'Revenue Growth': '-0.0659679536599087',
#    'SG&A Expense': '19298000000.0',
#    'Weighted Average Shs Out': '7313000000.0',
#    'Weighted Average Shs Out (Dil)': '7313000000.0',
#    'date': '2019-03-31'},
#   {'Consolidated Income': '4858000000.0',
#    'Cost of Revenue': '31247000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '6160000000.0',
#    'EBIT Margin': '0.128352051341',
#    'EBITDA': '16216000000.0',
#    'EBITDA Margin': '0.33788260788',
#    'EPS': '0.66',
#    'EPS Diluted': '0.66',
#    'Earnings Before Tax Margin': '0.114037463797',
#    'Earnings before Tax': '5473000000.0',
#    'Free Cash Flow margin': '0.167045194091',
#    'Gross Margin': '0.348925885025',
#    'Gross Profit': '16746000000.0',
#    'Income Tax Expense': '615000000.0',
#    'Interest Expense': '615000000.0',
#    'Net Income': '4858000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '4858000000.0',
#    'Net Profit Margin': '0.101223095035',
#    'Operating Expenses': '10586000000.0',
#    'Operating Income': '6160000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.101223095035',
#    'R&D Expenses': '0.0',
#    'Revenue': '47993000000.0',
#    'Revenue Growth': '0.0492796082118105',
#    'SG&A Expense': '21172000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2018-12-31'},
#   {'Consolidated Income': '4718000000.0',
#    'Cost of Revenue': '28872000000.0',
#    'Dividend per Share': '0.549901559897',
#    'EBIT': '7269000000.0',
#    'EBIT Margin': '0.158923457006',
#    'EBITDA': '16875000000.0',
#    'EBITDA Margin': '0.368941166182',
#    'EPS': '0.63',
#    'EPS Diluted': '0.63',
#    'Earnings Before Tax Margin': '0.133562167953',
#    'Earnings before Tax': '6109000000.0',
#    'Free Cash Flow margin': '0.144515621242',
#    'Gross Margin': '0.36876626074',
#    'Gross Profit': '16867000000.0',
#    'Income Tax Expense': '1391000000.0',
#    'Interest Expense': '1391000000.0',
#    'Net Income': '4718000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '4718000000.0',
#    'Net Profit Margin': '0.103150484269',
#    'Operating Expenses': '9598000000.0',
#    'Operating Income': '7269000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.103150484269',
#    'R&D Expenses': '0.0',
#    'Revenue': '45739000000.0',
#    'Revenue Growth': '0.173216026265839',
#    'SG&A Expense': '19196000000.0',
#    'Weighted Average Shs Out': '6603000000.0',
#    'Weighted Average Shs Out (Dil)': '6603000000.0',
#    'date': '2018-09-30'},
#   {'Consolidated Income': '5132000000.0',
#    'Cost of Revenue': '23836000000.0',
#    'Dividend per Share': '0.491289755474',
#    'EBIT': '6466000000.0',
#    'EBIT Margin': '0.165854409275',
#    'EBITDA': '13012000000.0',
#    'EBITDA Margin': '0.333760837224',
#    'EPS': '0.81',
#    'EPS Diluted': '0.81',
#    'Earnings Before Tax Margin': '0.170933155492',
#    'Earnings before Tax': '6664000000.0',
#    'Free Cash Flow margin': '0.134073770071',
#    'Gross Margin': '0.388601036269',
#    'Gross Profit': '15150000000.0',
#    'Income Tax Expense': '1532000000.0',
#    'Interest Expense': '1532000000.0',
#    'Net Income': '5132000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '5132000000.0',
#    'Net Profit Margin': '0.131636997897',
#    'Operating Expenses': '8684000000.0',
#    'Operating Income': '6466000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.131636997897',
#    'R&D Expenses': '0.0',
#    'Revenue': '38986000000.0',
#    'Revenue Growth': '0.0249224459750776',
#    'SG&A Expense': '17368000000.0',
#    'Weighted Average Shs Out': '6257000000.0',
#    'Weighted Average Shs Out (Dil)': '6257000000.0',
#    'date': '2018-06-30'},
#   {'Consolidated Income': '4662000000.0',
#    'Cost of Revenue': '23940000000.0',
#    'Dividend per Share': '0.498295731212',
#    'EBIT': '6201000000.0',
#    'EBIT Margin': '0.163021189337',
#    'EBITDA': '12195000000.0',
#    'EBITDA Margin': '0.320600452179',
#    'EPS': '0.75',
#    'EPS Diluted': '0.75',
#    'Earnings Before Tax Margin': '0.158893737841',
#    'Earnings before Tax': '6044000000.0',
#    'Free Cash Flow margin': '0.0786056049214',
#    'Gross Margin': '0.370629370629',
#    'Gross Profit': '14098000000.0',
#    'Income Tax Expense': '1382000000.0',
#    'Interest Expense': '1382000000.0',
#    'Net Income': '4662000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '4662000000.0',
#    'Net Profit Margin': '0.122561648877',
#    'Operating Expenses': '7897000000.0',
#    'Operating Income': '6201000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.122561648877',
#    'R&D Expenses': '0.0',
#    'Revenue': '38038000000.0',
#    'Revenue Growth': '-0.0872924464919858',
#    'SG&A Expense': '15794000000.0',
#    'Weighted Average Shs Out': '6161000000.0',
#    'Weighted Average Shs Out (Dil)': '6161000000.0',
#    'date': '2018-03-31'},
#   {'Consolidated Income': '19037000000.0',
#    'Cost of Revenue': '31317000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '359000000.0',
#    'EBIT Margin': '0.00861407044822',
#    'EBITDA': '6430000000.0',
#    'EBITDA Margin': '0.154285440061',
#    'EPS': '3.08',
#    'EPS Diluted': '3.07',
#    'Earnings Before Tax Margin': '-0.0331605720319',
#    'Earnings before Tax': '-1382000000.0',
#    'Free Cash Flow margin': '0.119637201267',
#    'Gross Margin': '0.248560322488',
#    'Gross Profit': '10359000000.0',
#    'Income Tax Expense': '-20419000000.0',
#    'Interest Expense': '-20419000000.0',
#    'Net Income': '19037000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '19037000000.0',
#    'Net Profit Margin': '0.456785680008',
#    'Operating Expenses': '10000000000.0',
#    'Operating Income': '359000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.456785680008',
#    'R&D Expenses': '0.0',
#    'Revenue': '41676000000.0',
#    'Revenue Growth': '0.0506201472219421',
#    'SG&A Expense': '20000000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2017-12-31'},
#   {'Consolidated Income': '3029000000.0',
#    'Cost of Revenue': '24948000000.0',
#    'Dividend per Share': '0.488157040883',
#    'EBIT': '6403000000.0',
#    'EBIT Margin': '0.161414742362',
#    'EBITDA': '12445000000.0',
#    'EBITDA Margin': '0.313728950287',
#    'EPS': '0.5',
#    'EPS Diluted': '0.5',
#    'Earnings Before Tax Margin': '0.123021074922',
#    'Earnings before Tax': '4880000000.0',
#    'Free Cash Flow margin': '0.153978017546',
#    'Gross Margin': '0.371079963699',
#    'Gross Profit': '14720000000.0',
#    'Income Tax Expense': '1851000000.0',
#    'Interest Expense': '1851000000.0',
#    'Net Income': '3029000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3029000000.0',
#    'Net Profit Margin': '0.0763587778562',
#    'Operating Expenses': '8317000000.0',
#    'Operating Income': '6403000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0763587778562',
#    'R&D Expenses': '0.0',
#    'Revenue': '39668000000.0',
#    'Revenue Growth': '-0.00424228732083239',
#    'SG&A Expense': '16634000000.0',
#    'Weighted Average Shs Out': '6164000000.0',
#    'Weighted Average Shs Out (Dil)': '6164000000.0',
#    'date': '2017-09-30'},
#   {'Consolidated Income': '3915000000.0',
#    'Cost of Revenue': '24401000000.0',
#    'Dividend per Share': '0.488485241648',
#    'EBIT': '7323000000.0',
#    'EBIT Margin': '0.183824083139',
#    'EBITDA': '13470000000.0',
#    'EBITDA Margin': '0.338127871075',
#    'EPS': '0.63',
#    'EPS Diluted': '0.63',
#    'Earnings Before Tax Margin': '0.149885784572',
#    'Earnings before Tax': '5971000000.0',
#    'Free Cash Flow margin': '0.0998067123528',
#    'Gross Margin': '0.387478976831',
#    'Gross Profit': '15436000000.0',
#    'Income Tax Expense': '2056000000.0',
#    'Interest Expense': '2056000000.0',
#    'Net Income': '3915000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3915000000.0',
#    'Net Profit Margin': '0.0982754725506',
#    'Operating Expenses': '8113000000.0',
#    'Operating Income': '7323000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0982754725506',
#    'R&D Expenses': '0.0',
#    'Revenue': '39837000000.0',
#    'Revenue Growth': '0.0119903467547314',
#    'SG&A Expense': '16226000000.0',
#    'Weighted Average Shs Out': '6166000000.0',
#    'Weighted Average Shs Out (Dil)': '6166000000.0',
#    'date': '2017-06-30'},
#   {'Consolidated Income': '3469000000.0',
#    'Cost of Revenue': '24014000000.0',
#    'Dividend per Share': '0.487998702562',
#    'EBIT': '6864000000.0',
#    'EBIT Margin': '0.174368093484',
#    'EBITDA': '12991000000.0',
#    'EBITDA Margin': '0.330013971802',
#    'EPS': '0.56',
#    'EPS Diluted': '0.56',
#    'Earnings Before Tax Margin': '0.133951479741',
#    'Earnings before Tax': '5273000000.0',
#    'Free Cash Flow margin': '0.0872348532961',
#    'Gross Margin': '0.389965705576',
#    'Gross Profit': '15351000000.0',
#    'Income Tax Expense': '1804000000.0',
#    'Interest Expense': '1804000000.0',
#    'Net Income': '3469000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3469000000.0',
#    'Net Profit Margin': '0.0881239679919',
#    'Operating Expenses': '8487000000.0',
#    'Operating Income': '6864000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0881239679919',
#    'R&D Expenses': '0.0',
#    'Revenue': '39365000000.0',
#    'Revenue Growth': '-0.0591764059176406',
#    'SG&A Expense': '16974000000.0',
#    'Weighted Average Shs Out': '6166000000.0',
#    'Weighted Average Shs Out (Dil)': '6166000000.0',
#    'date': '2017-03-31'},
#   {'Consolidated Income': '2064000000.0',
#    'Cost of Revenue': '27609000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '4248000000.0',
#    'EBIT Margin': '0.101527210153',
#    'EBITDA': '10377000000.0',
#    'EBITDA Margin': '0.248010324801',
#    'EPS': '0.4',
#    'EPS Diluted': '0.4',
#    'Earnings Before Tax Margin': '0.0654860065486',
#    'Earnings before Tax': '2740000000.0',
#    'Free Cash Flow margin': '0.0934251093425',
#    'Gross Margin': '0.340144834014',
#    'Gross Profit': '14232000000.0',
#    'Income Tax Expense': '676000000.0',
#    'Interest Expense': '676000000.0',
#    'Net Income': '2064000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '2064000000.0',
#    'Net Profit Margin': '0.049329604933',
#    'Operating Expenses': '9984000000.0',
#    'Operating Income': '4248000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.049329604933',
#    'R&D Expenses': '0.0',
#    'Revenue': '41841000000.0',
#    'Revenue Growth': '0.0232575201760822',
#    'SG&A Expense': '19968000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2016-12-31'},
#   {'Consolidated Income': '3328000000.0',
#    'Cost of Revenue': '25469000000.0',
#    'Dividend per Share': '0.478204504942',
#    'EBIT': '6408000000.0',
#    'EBIT Margin': '0.156713132795',
#    'EBITDA': '12987000000.0',
#    'EBITDA Margin': '0.317608217168',
#    'EPS': '0.53',
#    'EPS Diluted': '0.53',
#    'Earnings Before Tax Margin': '0.124798239178',
#    'Earnings before Tax': '5103000000.0',
#    'Free Cash Flow margin': '0.132404010761',
#    'Gross Margin': '0.377133773539',
#    'Gross Profit': '15421000000.0',
#    'Income Tax Expense': '1775000000.0',
#    'Interest Expense': '1775000000.0',
#    'Net Income': '3328000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3328000000.0',
#    'Net Profit Margin': '0.0813890926877',
#    'Operating Expenses': '9013000000.0',
#    'Operating Income': '6408000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0813890926877',
#    'R&D Expenses': '0.0',
#    'Revenue': '40890000000.0',
#    'Revenue Growth': '0.00913129318854886',
#    'SG&A Expense': '18026000000.0',
#    'Weighted Average Shs Out': '6171000000.0',
#    'Weighted Average Shs Out (Dil)': '6171000000.0',
#    'date': '2016-09-30'},
#   {'Consolidated Income': '3408000000.0',
#    'Cost of Revenue': '25051000000.0',
#    'Dividend per Share': '0.478211566499',
#    'EBIT': '6560000000.0',
#    'EBIT Margin': '0.161895360316',
#    'EBITDA': '13136000000.0',
#    'EBITDA Margin': '0.324185587364',
#    'EPS': '0.55',
#    'EPS Diluted': '0.56',
#    'Earnings Before Tax Margin': '0.131145113524',
#    'Earnings before Tax': '5314000000.0',
#    'Free Cash Flow margin': '0.124777887463',
#    'Gross Margin': '0.381762092794',
#    'Gross Profit': '15469000000.0',
#    'Income Tax Expense': '1906000000.0',
#    'Interest Expense': '1906000000.0',
#    'Net Income': '3408000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3408000000.0',
#    'Net Profit Margin': '0.0841066140178',
#    'Operating Expenses': '8909000000.0',
#    'Operating Income': '6560000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0841066140178',
#    'R&D Expenses': '0.0',
#    'Revenue': '40520000000.0',
#    'Revenue Growth': '-0.000370050573578389',
#    'SG&A Expense': '17818000000.0',
#    'Weighted Average Shs Out': '6173000000.0',
#    'Weighted Average Shs Out (Dil)': '6173000000.0',
#    'date': '2016-06-30'},
#   {'Consolidated Income': '3803000000.0',
#    'Cost of Revenue': '24963000000.0',
#    'Dividend per Share': '0.477478937135',
#    'EBIT': '7131000000.0',
#    'EBIT Margin': '0.175922042679',
#    'EBITDA': '13694000000.0',
#    'EBITDA Margin': '0.337831503639',
#    'EPS': '0.62',
#    'EPS Diluted': '0.61',
#    'Earnings Before Tax Margin': '0.146169976563',
#    'Earnings before Tax': '5925000000.0',
#    'Free Cash Flow margin': '0.0850869618848',
#    'Gross Margin': '0.384161835451',
#    'Gross Profit': '15572000000.0',
#    'Income Tax Expense': '2122000000.0',
#    'Interest Expense': '2122000000.0',
#    'Net Income': '3803000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3803000000.0',
#    'Net Profit Margin': '0.0938201554212',
#    'Operating Expenses': '8441000000.0',
#    'Operating Income': '7131000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0938201554212',
#    'R&D Expenses': '0.0',
#    'Revenue': '40535000000.0',
#    'Revenue Growth': '-0.723877902739082',
#    'SG&A Expense': '16882000000.0',
#    'Weighted Average Shs Out': '6172000000.0',
#    'Weighted Average Shs Out (Dil)': '6172000000.0',
#    'date': '2016-03-31'},
#   {'Consolidated Income': '13345000000.0',
#    'Cost of Revenue': '1.22016e+11',
#    'Dividend per Share': '0.0',
#    'EBIT': '24785000000.0',
#    'EBIT Margin': '0.168833999768',
#    'EBITDA': '46801000000.0',
#    'EBITDA Margin': '0.318805730206',
#    'EPS': '2.37',
#    'EPS Diluted': '2.37',
#    'Earnings Before Tax Margin': '0.138623033903',
#    'Earnings before Tax': '20350000000.0',
#    'Free Cash Flow margin': '0.113500589233',
#    'Gross Margin': '0.168833999768',
#    'Gross Profit': '24785000000.0',
#    'Income Tax Expense': '7005000000.0',
#    'Interest Expense': '7005000000.0',
#    'Net Income': '13345000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '13345000000.0',
#    'Net Profit Margin': '0.090905375304',
#    'Operating Expenses': '0.0',
#    'Operating Income': '24785000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.090905375304',
#    'R&D Expenses': '0.0',
#    'Revenue': '1.46801e+11',
#    'Revenue Growth': '-3.23812718208291',
#    'SG&A Expense': '0.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2015-12-31'},
#   {'Consolidated Income': '-6244000000.0',
#    'Cost of Revenue': '-38995000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '-11168000000.0',
#    'EBIT Margin': '0.170267262277',
#    'EBITDA': '-20442000000.0',
#    'EBITDA Margin': '0.3116586117',
#    'EPS': '-1.2',
#    'EPS Diluted': '-1.2',
#    'Earnings Before Tax Margin': '0.141940205211',
#    'Earnings before Tax': '-9310000000.0',
#    'Free Cash Flow margin': '0.115412175451',
#    'Gross Margin': '0.405482459484',
#    'Gross Profit': '-26596000000.0',
#    'Income Tax Expense': '-3066000000.0',
#    'Interest Expense': '-3066000000.0',
#    'Net Income': '-6244000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '-6244000000.0',
#    'Net Profit Margin': '0.0951959872543',
#    'Operating Expenses': '-15428000000.0',
#    'Operating Income': '-11168000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0951959872543',
#    'R&D Expenses': '0.0',
#    'Revenue': '-65591000000.0',
#    'Revenue Growth': '-2.67790540022',
#    'SG&A Expense': '-30856000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2015-10-28'},
#   {'Consolidated Income': '3078000000.0',
#    'Cost of Revenue': '17796000000.0',
#    'Dividend per Share': '0.47',
#    'EBIT': '5797000000.0',
#    'EBIT Margin': '0.1483',
#    'EBITDA': '12062000000.0',
#    'EBITDA Margin': '0.309',
#    'EPS': '0.5',
#    'EPS Diluted': '0.5',
#    'Earnings Before Tax Margin': '0.119',
#    'Earnings before Tax': '4651000000.0',
#    'Free Cash Flow margin': '0.1476',
#    'Gross Margin': '0.5448',
#    'Gross Profit': '21295000000.0',
#    'Income Tax Expense': '1657000000.0',
#    'Interest Expense': '1146000000.0',
#    'Net Income': '2994000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '84000000.0',
#    'Net Income Com': '2994000000.0',
#    'Net Profit Margin': '0.0766',
#    'Operating Expenses': '15372000000.0',
#    'Operating Income': '5923000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.077',
#    'R&D Expenses': '0.0',
#    'Revenue': '39091000000.0',
#    'Revenue Growth': '0.184037558685446',
#    'SG&A Expense': '9107000000.0',
#    'Weighted Average Shs Out': '6151000000.0',
#    'Weighted Average Shs Out (Dil)': '5924000000.0',
#    'date': '2015-09-30'},
#   {'Consolidated Income': '3044000000.0',
#    'Cost of Revenue': '19836000000.0',
#    'Dividend per Share': '0.468677940046',
#    'EBIT': '5712000000.0',
#    'EBIT Margin': '0.173012267151',
#    'EBITDA': '10408000000.0',
#    'EBITDA Margin': '0.315250643647',
#    'EPS': '0.59',
#    'EPS Diluted': '0.59',
#    'Earnings Before Tax Margin': '0.14414660003',
#    'Earnings before Tax': '4759000000.0',
#    'Free Cash Flow margin': '0.141753748296',
#    'Gross Margin': '0.399182189914',
#    'Gross Profit': '13179000000.0',
#    'Income Tax Expense': '1715000000.0',
#    'Interest Expense': '1715000000.0',
#    'Net Income': '3044000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3044000000.0',
#    'Net Profit Margin': '0.0922005149175',
#    'Operating Expenses': '7467000000.0',
#    'Operating Income': '5712000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0922005149175',
#    'R&D Expenses': '0.0',
#    'Revenue': '33015000000.0',
#    'Revenue Growth': '0.0134761787819253',
#    'SG&A Expense': '14934000000.0',
#    'Weighted Average Shs Out': '5204000000.0',
#    'Weighted Average Shs Out (Dil)': '5204000000.0',
#    'date': '2015-06-30'},
#   {'Consolidated Income': '3200000000.0',
#    'Cost of Revenue': '19159000000.0',
#    'Dividend per Share': '0.467807034403',
#    'EBIT': '5456000000.0',
#    'EBIT Margin': '0.167485265226',
#    'EBITDA': '10034000000.0',
#    'EBITDA Margin': '0.308018172888',
#    'EPS': '0.61',
#    'EPS Diluted': '0.61',
#    'Earnings Before Tax Margin': '0.139704076621',
#    'Earnings before Tax': '4551000000.0',
#    'Free Cash Flow margin': '0.0887156188605',
#    'Gross Margin': '0.411867632613',
#    'Gross Profit': '13417000000.0',
#    'Income Tax Expense': '1351000000.0',
#    'Interest Expense': '1351000000.0',
#    'Net Income': '3200000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3200000000.0',
#    'Net Profit Margin': '0.098231827112',
#    'Operating Expenses': '7961000000.0',
#    'Operating Income': '5456000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.098231827112',
#    'R&D Expenses': '0.0',
#    'Revenue': '32576000000.0',
#    'Revenue Growth': '-0.0540956473765208',
#    'SG&A Expense': '15922000000.0',
#    'Weighted Average Shs Out': '5203000000.0',
#    'Weighted Average Shs Out (Dil)': '5203000000.0',
#    'date': '2015-03-31'},
#   {'Consolidated Income': '-3977000000.0',
#    'Cost of Revenue': '25224000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '-5550000000.0',
#    'EBIT Margin': '-0.161154505067',
#    'EBITDA': '-983000000.0',
#    'EBITDA Margin': '-0.0285432213479',
#    'EPS': '-0.77',
#    'EPS Diluted': '-0.76',
#    'Earnings Before Tax Margin': '-0.183048288278',
#    'Earnings before Tax': '-6304000000.0',
#    'Free Cash Flow margin': '0.0399256656697',
#    'Gross Margin': '0.267574552107',
#    'Gross Profit': '9215000000.0',
#    'Income Tax Expense': '-2327000000.0',
#    'Interest Expense': '-2327000000.0',
#    'Net Income': '-3977000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '-3977000000.0',
#    'Net Profit Margin': '-0.115479543541',
#    'Operating Expenses': '14765000000.0',
#    'Operating Income': '-5550000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '-0.115479543541',
#    'R&D Expenses': '0.0',
#    'Revenue': '34439000000.0',
#    'Revenue Growth': '0.0449676851655187',
#    'SG&A Expense': '29530000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2014-12-31'},
#   {'Consolidated Income': '3002000000.0',
#    'Cost of Revenue': '28247000000.0',
#    'Dividend per Share': '0.458141321045',
#    'EBIT': '5402000000.0',
#    'EBIT Margin': '0.163910550111',
#    'EBITDA': '9941000000.0',
#    'EBITDA Margin': '0.301635464393',
#    'EPS': '0.58',
#    'EPS Diluted': '0.57',
#    'Earnings Before Tax Margin': '0.132566677792',
#    'Earnings before Tax': '4369000000.0',
#    'Free Cash Flow margin': '0.107534059532',
#    'Gross Margin': '0.14291349334',
#    'Gross Profit': '4710000000.0',
#    'Income Tax Expense': '1367000000.0',
#    'Interest Expense': '1367000000.0',
#    'Net Income': '3002000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3002000000.0',
#    'Net Profit Margin': '0.0910883878994',
#    'Operating Expenses': '-28225000000.0',
#    'Operating Income': '5402000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.0910883878994',
#    'R&D Expenses': '0.0',
#    'Revenue': '32957000000.0',
#    'Revenue Growth': '-0.493366743017017',
#    'SG&A Expense': '16950000000.0',
#    'Weighted Average Shs Out': '5208000000.0',
#    'Weighted Average Shs Out (Dil)': '5208000000.0',
#    'date': '2014-09-30'},
#   {'Consolidated Income': '7199000000.0',
#    'Cost of Revenue': '27533000000.0',
#    'Dividend per Share': '0.917705735661',
#    'EBIT': '11894000000.0',
#    'EBIT Margin': '0.182841155401',
#    'EBITDA': '21061000000.0',
#    'EBITDA Margin': '0.323761356474',
#    'EPS': '1.38',
#    'EPS Diluted': '1.38',
#    'Earnings Before Tax Margin': '0.178336997125',
#    'Earnings before Tax': '11601000000.0',
#    'Free Cash Flow margin': '0.0802447310572',
#    'Gross Margin': '0.576747475058',
#    'Gross Profit': '37518000000.0',
#    'Income Tax Expense': '4402000000.0',
#    'Interest Expense': '4402000000.0',
#    'Net Income': '7199000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '7199000000.0',
#    'Net Profit Margin': '0.110667015111',
#    'Operating Expenses': '53157000000.0',
#    'Operating Income': '11894000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.110667015111',
#    'R&D Expenses': '0.0',
#    'Revenue': '65051000000.0',
#    'Revenue Growth': '-1.50524263700758',
#    'SG&A Expense': '32914000000.0',
#    'Weighted Average Shs Out': '5213000000.0',
#    'Weighted Average Shs Out (Dil)': '5213000000.0',
#    'date': '2014-06-30'},
#   {'Consolidated Income': '-18249000000.0',
#    'Cost of Revenue': '-51464000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '-30479000000.0',
#    'EBIT Margin': '0.236726419784',
#    'EBITDA': '-48874000000.0',
#    'EBITDA Margin': '0.379597986827',
#    'EPS': '-3.39',
#    'EPS Diluted': '-3.39',
#    'Earnings Before Tax Margin': '0.213379209643',
#    'Earnings before Tax': '-27473000000.0',
#    'Free Cash Flow margin': '0.107586678265',
#    'Gross Margin': '0.600285820803',
#    'Gross Profit': '-77288000000.0',
#    'Income Tax Expense': '-9224000000.0',
#    'Interest Expense': '-9224000000.0',
#    'Net Income': '-18249000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '-18249000000.0',
#    'Net Profit Margin': '0.141737604076',
#    'Operating Expenses': '-98273000000.0',
#    'Operating Income': '-30479000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.141737604076',
#    'R&D Expenses': '0.0',
#    'Revenue': '-1.28752e+11',
#    'Revenue Growth': '-4.88239905919247',
#    'SG&A Expense': '-56828000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2014-03-31'},
#   {'Consolidated Income': '6913000000.0',
#    'Cost of Revenue': '12237000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '12238000000.0',
#    'EBIT Margin': '0.369025721437',
#    'EBITDA': '16918000000.0',
#    'EBITDA Margin': '0.510146850406',
#    'EPS': '1.29',
#    'EPS Diluted': '1.3',
#    'Earnings Before Tax Margin': '0.333835901456',
#    'Earnings before Tax': '11071000000.0',
#    'Free Cash Flow margin': '0.0765310737871',
#    'Gross Margin': '0.631004432651',
#    'Gross Profit': '20926000000.0',
#    'Income Tax Expense': '4158000000.0',
#    'Interest Expense': '4158000000.0',
#    'Net Income': '6913000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '6913000000.0',
#    'Net Profit Margin': '0.208455206103',
#    'Operating Expenses': '20925000000.0',
#    'Operating Income': '12238000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.208455206103',
#    'R&D Expenses': '0.0',
#    'Revenue': '33163000000.0',
#    'Revenue Growth': '0.0312519435288264',
#    'SG&A Expense': '8016000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2013-12-31'},
#   {'Consolidated Income': '3814000000.0',
#    'Cost of Revenue': '13403000000.0',
#    'Dividend per Share': '0.443354313217',
#    'EBIT': '6188000000.0',
#    'EBIT Margin': '0.192424902046',
#    'EBITDA': '10803000000.0',
#    'EBITDA Margin': '0.335935070589',
#    'EPS': '0.72',
#    'EPS Diluted': '0.71',
#    'Earnings Before Tax Margin': '0.168200758754',
#    'Earnings before Tax': '5409000000.0',
#    'Free Cash Flow margin': '0.101623235276',
#    'Gross Margin': '0.583214130232',
#    'Gross Profit': '18755000000.0',
#    'Income Tax Expense': '1595000000.0',
#    'Interest Expense': '1595000000.0',
#    'Net Income': '3814000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3814000000.0',
#    'Net Profit Margin': '0.118601903103',
#    'Operating Expenses': '25970000000.0',
#    'Operating Income': '6188000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.118601903103',
#    'R&D Expenses': '0.0',
#    'Revenue': '32158000000.0',
#    'Revenue Growth': '0.00258768511301637',
#    'SG&A Expense': '15904000000.0',
#    'Weighted Average Shs Out': '5402000000.0',
#    'Weighted Average Shs Out (Dil)': '5402000000.0',
#    'date': '2013-09-30'},
#   {'Consolidated Income': '3822000000.0',
#    'Cost of Revenue': '13270000000.0',
#    'Dividend per Share': '0.445831803158',
#    'EBIT': '6113000000.0',
#    'EBIT Margin': '0.19058456742',
#    'EBITDA': '10684000000.0',
#    'EBITDA Margin': '0.33309431021',
#    'EPS': '0.71',
#    'EPS Diluted': '0.71',
#    'Earnings Before Tax Margin': '0.17883086516',
#    'Earnings before Tax': '5736000000.0',
#    'Free Cash Flow margin': '0.127794232268',
#    'Gross Margin': '0.586282151208',
#    'Gross Profit': '18805000000.0',
#    'Income Tax Expense': '1914000000.0',
#    'Interest Expense': '1914000000.0',
#    'Net Income': '3822000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3822000000.0',
#    'Net Profit Margin': '0.119158222915',
#    'Operating Expenses': '25962000000.0',
#    'Operating Income': '6113000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.119158222915',
#    'R&D Expenses': '0.0',
#    'Revenue': '32075000000.0',
#    'Revenue Growth': '0.0229302206914147',
#    'SG&A Expense': '16242000000.0',
#    'Weighted Average Shs Out': '5446000000.0',
#    'Weighted Average Shs Out (Dil)': '5446000000.0',
#    'date': '2013-06-30'},
#   {'Consolidated Income': '3700000000.0',
#    'Cost of Revenue': '12554000000.0',
#    'Dividend per Share': '0.453836386722',
#    'EBIT': '5940000000.0',
#    'EBIT Margin': '0.189437428243',
#    'EBITDA': '10469000000.0',
#    'EBITDA Margin': '0.333875494323',
#    'EPS': '0.67',
#    'EPS Diluted': '0.67',
#    'Earnings Before Tax Margin': '0.167655313178',
#    'Earnings before Tax': '5257000000.0',
#    'Free Cash Flow margin': '0.125877025131',
#    'Gross Margin': '0.599630054854',
#    'Gross Profit': '18802000000.0',
#    'Income Tax Expense': '1557000000.0',
#    'Interest Expense': '1557000000.0',
#    'Net Income': '3700000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3700000000.0',
#    'Net Profit Margin': '0.117999744865',
#    'Operating Expenses': '25416000000.0',
#    'Operating Income': '5940000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.117999744865',
#    'R&D Expenses': '0.0',
#    'Revenue': '31356000000.0',
#    'Revenue Growth': '-0.0375099760574621',
#    'SG&A Expense': '16666000000.0',
#    'Weighted Average Shs Out': '5513000000.0',
#    'Weighted Average Shs Out (Dil)': '5513000000.0',
#    'date': '2013-03-31'},
#   {'Consolidated Income': '-3857000000.0',
#    'Cost of Revenue': '17215000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '-5958000000.0',
#    'EBIT Margin': '-0.182884154951',
#    'EBITDA': '-1386000000.0',
#    'EBITDA Margin': '-0.0425440481306',
#    'EPS': '-0.65',
#    'EPS Diluted': '-0.65',
#    'Earnings Before Tax Margin': '-0.203480876665',
#    'Earnings before Tax': '-6629000000.0',
#    'Free Cash Flow margin': '0.134630732396',
#    'Gross Margin': '0.471575910123',
#    'Gross Profit': '15363000000.0',
#    'Income Tax Expense': '-2772000000.0',
#    'Interest Expense': '-2772000000.0',
#    'Net Income': '-3857000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '-3857000000.0',
#    'Net Profit Margin': '-0.118392780404',
#    'Operating Expenses': '38536000000.0',
#    'Operating Income': '-5958000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '-0.118392780404',
#    'R&D Expenses': '0.0',
#    'Revenue': '32578000000.0',
#    'Revenue Growth': '0.0355701071235576',
#    'SG&A Expense': '33498000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2012-12-31'},
#   {'Consolidated Income': '3635000000.0',
#    'Cost of Revenue': '12718000000.0',
#    'Dividend per Share': '0.43621751026',
#    'EBIT': '6037000000.0',
#    'EBIT Margin': '0.191900568995',
#    'EBITDA': '10549000000.0',
#    'EBITDA Margin': '0.335325344099',
#    'EPS': '0.63',
#    'EPS Diluted': '0.63',
#    'Earnings Before Tax Margin': '0.170889093741',
#    'Earnings before Tax': '5376000000.0',
#    'Free Cash Flow margin': '0.210051177723',
#    'Gross Margin': '0.595727772656',
#    'Gross Profit': '18741000000.0',
#    'Income Tax Expense': '1741000000.0',
#    'Interest Expense': '1741000000.0',
#    'Net Income': '3635000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3635000000.0',
#    'Net Profit Margin': '0.115547220191',
#    'Operating Expenses': '25422000000.0',
#    'Operating Income': '6037000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.115547220191',
#    'R&D Expenses': '0.0',
#    'Revenue': '31459000000.0',
#    'Revenue Growth': '-0.00367379255740301',
#    'SG&A Expense': '16384000000.0',
#    'Weighted Average Shs Out': '5848000000.0',
#    'Weighted Average Shs Out (Dil)': '5848000000.0',
#    'date': '2012-09-30'},
#   {'Consolidated Income': '3902000000.0',
#    'Cost of Revenue': '12369000000.0',
#    'Dividend per Share': '0.438498131159',
#    'EBIT': '6817000000.0',
#    'EBIT Margin': '0.215898653998',
#    'EBITDA': '11316000000.0',
#    'EBITDA Margin': '0.3583847981',
#    'EPS': '0.67',
#    'EPS Diluted': '0.67',
#    'Earnings Before Tax Margin': '0.189010292953',
#    'Earnings before Tax': '5968000000.0',
#    'Free Cash Flow margin': '0.164117181314',
#    'Gross Margin': '0.608266033254',
#    'Gross Profit': '19206000000.0',
#    'Income Tax Expense': '2066000000.0',
#    'Interest Expense': '2066000000.0',
#    'Net Income': '3902000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3902000000.0',
#    'Net Profit Margin': '0.123578780681',
#    'Operating Expenses': '24758000000.0',
#    'Operating Income': '6817000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.123578780681',
#    'R&D Expenses': '0.0',
#    'Revenue': '31575000000.0',
#    'Revenue Growth': '-0.00776192571177173',
#    'SG&A Expense': '15780000000.0',
#    'Weighted Average Shs Out': '5886000000.0',
#    'Weighted Average Shs Out (Dil)': '5886000000.0',
#    'date': '2012-06-30'},
#   {'Consolidated Income': '3584000000.0',
#    'Cost of Revenue': '12913000000.0',
#    'Dividend per Share': '0.440351470091',
#    'EBIT': '6101000000.0',
#    'EBIT Margin': '0.191722707561',
#    'EBITDA': '10661000000.0',
#    'EBITDA Margin': '0.335019797624',
#    'EPS': '0.6',
#    'EPS Diluted': '0.6',
#    'Earnings Before Tax Margin': '0.171233737666',
#    'Earnings before Tax': '5449000000.0',
#    'Free Cash Flow margin': '0.1110866696',
#    'Gross Margin': '0.594211551757',
#    'Gross Profit': '18909000000.0',
#    'Income Tax Expense': '1865000000.0',
#    'Interest Expense': '1865000000.0',
#    'Net Income': '3584000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3584000000.0',
#    'Net Profit Margin': '0.112626484822',
#    'Operating Expenses': '25721000000.0',
#    'Operating Income': '6101000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.112626484822',
#    'R&D Expenses': '0.0',
#    'Revenue': '31822000000.0',
#    'Revenue Growth': '-0.0209519121311879',
#    'SG&A Expense': '16496000000.0',
#    'Weighted Average Shs Out': '5918000000.0',
#    'Weighted Average Shs Out (Dil)': '5918000000.0',
#    'date': '2012-03-31'},
#   {'Consolidated Income': '-6678000000.0',
#    'Cost of Revenue': '17474000000.0',
#    'Dividend per Share': '0.0',
#    'EBIT': '-8990000000.0',
#    'EBIT Margin': '-0.276589853244',
#    'EBITDA': '-4417000000.0',
#    'EBITDA Margin': '-0.13589514814',
#    'EPS': '-1.13',
#    'EPS Diluted': '-1.13',
#    'Earnings Before Tax Margin': '-0.29966464634',
#    'Earnings before Tax': '-9740000000.0',
#    'Free Cash Flow margin': '0.0619327446697',
#    'Gross Margin': '0.462388087253',
#    'Gross Profit': '15029000000.0',
#    'Income Tax Expense': '-3062000000.0',
#    'Interest Expense': '-3062000000.0',
#    'Net Income': '-6678000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '-6678000000.0',
#    'Net Profit Margin': '-0.205457957727',
#    'Operating Expenses': '41493000000.0',
#    'Operating Income': '-8990000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '-0.205457957727',
#    'R&D Expenses': '0.0',
#    'Revenue': '32503000000.0',
#    'Revenue Growth': '0.0325624245504797',
#    'SG&A Expense': '33072000000.0',
#    'Weighted Average Shs Out': '0.0',
#    'Weighted Average Shs Out (Dil)': '0.0',
#    'date': '2011-12-31'},
#   {'Consolidated Income': '3623000000.0',
#    'Cost of Revenue': '13165000000.0',
#    'Dividend per Share': '0.429101331984',
#    'EBIT': '6235000000.0',
#    'EBIT Margin': '0.198074845924',
#    'EBITDA': '10853000000.0',
#    'EBITDA Margin': '0.344780481606',
#    'EPS': '0.61',
#    'EPS Diluted': '0.61',
#    'Earnings Before Tax Margin': '0.175424105725',
#    'Earnings before Tax': '5522000000.0',
#    'Free Cash Flow margin': '0.164336997268',
#    'Gross Margin': '0.581771395896',
#    'Gross Profit': '18313000000.0',
#    'Income Tax Expense': '1899000000.0',
#    'Interest Expense': '1899000000.0',
#    'Net Income': '3623000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3623000000.0',
#    'Net Profit Margin': '0.115096257704',
#    'Operating Expenses': '25243000000.0',
#    'Operating Income': '6235000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.115096257704',
#    'R&D Expenses': '0.0',
#    'Revenue': '31478000000.0',
#    'Revenue Growth': '-0.00053976821717733',
#    'SG&A Expense': '14920000000.0',
#    'Weighted Average Shs Out': '5931000000.0',
#    'Weighted Average Shs Out (Dil)': '5931000000.0',
#    'date': '2011-09-30'},
#   {'Consolidated Income': '3591000000.0',
#    'Cost of Revenue': '13332000000.0',
#    'Dividend per Share': '0.428740091078',
#    'EBIT': '6165000000.0',
#    'EBIT Margin': '0.195745356406',
#    'EBITDA': '10767000000.0',
#    'EBITDA Margin': '0.341863787903',
#    'EPS': '0.61',
#    'EPS Diluted': '0.61',
#    'Earnings Before Tax Margin': '0.174122876647',
#    'Earnings before Tax': '5484000000.0',
#    'Free Cash Flow margin': '0.11916177171',
#    'Gross Margin': '0.576694713447',
#    'Gross Profit': '18163000000.0',
#    'Income Tax Expense': '1893000000.0',
#    'Interest Expense': '1893000000.0',
#    'Net Income': '3591000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3591000000.0',
#    'Net Profit Margin': '0.114018098111',
#    'Operating Expenses': '25330000000.0',
#    'Operating Income': '6165000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.114018098111',
#    'R&D Expenses': '0.0',
#    'Revenue': '31495000000.0',
#    'Revenue Growth': '0.0079367619291452',
#    'SG&A Expense': '14792000000.0',
#    'Weighted Average Shs Out': '5929000000.0',
#    'Weighted Average Shs Out (Dil)': '5929000000.0',
#    'date': '2011-06-30'},
#   {'Consolidated Income': '3408000000.0',
#    'Cost of Revenue': '13403000000.0',
#    'Dividend per Share': '0.428691983122',
#    'EBIT': '5808000000.0',
#    'EBIT Margin': '0.185873843889',
#    'EBITDA': '10392000000.0',
#    'EBITDA Margin': '0.332575927289',
#    'EPS': '0.57',
#    'EPS Diluted': '0.57',
#    'Earnings Before Tax Margin': '0.166736006657',
#    'Earnings before Tax': '5210000000.0',
#    'Free Cash Flow margin': '0.115179057189',
#    'Gross Margin': '0.571062822031',
#    'Gross Profit': '17844000000.0',
#    'Income Tax Expense': '1802000000.0',
#    'Interest Expense': '1802000000.0',
#    'Net Income': '3408000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income Com': '3408000000.0',
#    'Net Profit Margin': '0.109066470381',
#    'Operating Expenses': '25439000000.0',
#    'Operating Income': '5808000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.109066470381',
#    'R&D Expenses': '0.0',
#    'Revenue': '31247000000.0',
#    'Revenue Growth': '-0.00363508816683141',
#    'SG&A Expense': '14904000000.0',
#    'Weighted Average Shs Out': '5925000000.0',
#    'Weighted Average Shs Out (Dil)': '5925000000.0',
#    'date': '2011-03-31'},
#   {'Consolidated Income': '1161000000.0',
#    'Cost of Revenue': '11817000000.0',
#    'Dividend per Share': '0.42',
#    'EBIT': '2223000000.0',
#    'EBIT Margin': '0.0709',
#    'EBITDA': '7130000000.0',
#    'EBITDA Margin': '0.227',
#    'EPS': '0.18',
#    'EPS Diluted': '0.19',
#    'Earnings Before Tax Margin': '0.0471',
#    'Earnings before Tax': '1477000000.0',
#    'Free Cash Flow margin': '0.112',
#    'Gross Margin': '0.6232',
#    'Gross Profit': '19544000000.0',
#    'Income Tax Expense': '388000000.0',
#    'Interest Expense': '746000000.0',
#    'Net Income': '1089000000.0',
#    'Net Income - Discontinued ops': '-2000000.0',
#    'Net Income - Non-Controlling int': '72000000.0',
#    'Net Income Com': '1089000000.0',
#    'Net Profit Margin': '0.0347',
#    'Operating Expenses': '17456000000.0',
#    'Operating Income': '2088000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.035',
#    'R&D Expenses': '0.0',
#    'Revenue': '31361000000.0',
#    'Revenue Growth': '-0.00696621386276559',
#    'SG&A Expense': '12464000000.0',
#    'Weighted Average Shs Out': '5910000000.0',
#    'Weighted Average Shs Out (Dil)': '5910000000.0',
#    'date': '2010-12-31'},
#   {'Consolidated Income': '12396000000.0',
#    'Cost of Revenue': '13605000000.0',
#    'Dividend per Share': '0.42',
#    'EBIT': '6475000000.0',
#    'EBIT Margin': '0.205',
#    'EBITDA': '11348000000.0',
#    'EBITDA Margin': '0.359',
#    'EPS': '2.08',
#    'EPS Diluted': '2.07',
#    'Earnings Before Tax Margin': '0.1819',
#    'Earnings before Tax': '5746000000.0',
#    'Free Cash Flow margin': '0.1338',
#    'Gross Margin': '0.5692',
#    'Gross Profit': '17976000000.0',
#    'Income Tax Expense': '-6573000000.0',
#    'Interest Expense': '729000000.0',
#    'Net Income': '12319000000.0',
#    'Net Income - Discontinued ops': '-780000000.0',
#    'Net Income - Non-Controlling int': '77000000.0',
#    'Net Income Com': '12319000000.0',
#    'Net Profit Margin': '0.3901',
#    'Operating Expenses': '12545000000.0',
#    'Operating Income': '5431000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.39',
#    'R&D Expenses': '0.0',
#    'Revenue': '31581000000.0',
#    'Revenue Growth': '0.0250908854842898',
#    'SG&A Expense': '7672000000.0',
#    'Weighted Average Shs Out': '5909000000.0',
#    'Weighted Average Shs Out (Dil)': '5909000000.0',
#    'date': '2010-09-30'},
#   {'Consolidated Income': '4082000000.0',
#    'Cost of Revenue': '12452000000.0',
#    'Dividend per Share': '0.42',
#    'EBIT': '6917000000.0',
#    'EBIT Margin': '0.2245',
#    'EBITDA': '11736000000.0',
#    'EBITDA Margin': '0.381',
#    'EPS': '0.68',
#    'EPS Diluted': '0.67',
#    'Earnings Before Tax Margin': '0.2',
#    'Earnings before Tax': '6163000000.0',
#    'Free Cash Flow margin': '0.1255',
#    'Gross Margin': '0.5958',
#    'Gross Profit': '18356000000.0',
#    'Income Tax Expense': '2160000000.0',
#    'Interest Expense': '754000000.0',
#    'Net Income': '4003000000.0',
#    'Net Income - Discontinued ops': '5000000.0',
#    'Net Income - Non-Controlling int': '79000000.0',
#    'Net Income Com': '4003000000.0',
#    'Net Profit Margin': '0.1299',
#    'Operating Expenses': '12273000000.0',
#    'Operating Income': '6083000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.13',
#    'R&D Expenses': '0.0',
#    'Revenue': '30808000000.0',
#    'Revenue Growth': '0.0091057975761546',
#    'SG&A Expense': '7454000000.0',
#    'Weighted Average Shs Out': '5909000000.0',
#    'Weighted Average Shs Out (Dil)': '5909000000.0',
#    'date': '2010-06-30'},
#   {'Consolidated Income': '2540000000.0',
#    'Cost of Revenue': '12383000000.0',
#    'Dividend per Share': '0.42',
#    'EBIT': '6081000000.0',
#    'EBIT Margin': '0.1992',
#    'EBITDA': '10861000000.0',
#    'EBITDA Margin': '0.356',
#    'EPS': '0.42',
#    'EPS Diluted': '0.41',
#    'Earnings Before Tax Margin': '0.1741',
#    'Earnings before Tax': '5316000000.0',
#    'Free Cash Flow margin': '0.134',
#    'Gross Margin': '0.5944',
#    'Gross Profit': '18147000000.0',
#    'Income Tax Expense': '2863000000.0',
#    'Interest Expense': '765000000.0',
#    'Net Income': '2453000000.0',
#    'Net Income - Discontinued ops': '-2000000.0',
#    'Net Income - Non-Controlling int': '87000000.0',
#    'Net Income Com': '2453000000.0',
#    'Net Profit Margin': '0.0803',
#    'Operating Expenses': '12176000000.0',
#    'Operating Income': '5971000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.08',
#    'R&D Expenses': '0.0',
#    'Revenue': '30530000000.0',
#    'Revenue Growth': '-0.00579653510485867',
#    'SG&A Expense': '7396000000.0',
#    'Weighted Average Shs Out': '5902074438.0',
#    'Weighted Average Shs Out (Dil)': '5905000000.0',
#    'date': '2010-03-31'},
#   {'Consolidated Income': '2695000000.0',
#    'Cost of Revenue': '12974000000.0',
#    'Dividend per Share': '0.41',
#    'EBIT': '4622000000.0',
#    'EBIT Margin': '0.1505',
#    'EBITDA': '9523000000.0',
#    'EBITDA Margin': '0.31',
#    'EPS': '0.45',
#    'EPS Diluted': '0.44',
#    'Earnings Before Tax Margin': '0.1246',
#    'Earnings before Tax': '3827000000.0',
#    'Free Cash Flow margin': '0.1121',
#    'Gross Margin': '0.5775',
#    'Gross Profit': '17734000000.0',
#    'Income Tax Expense': '1205000000.0',
#    'Interest Expense': '795000000.0',
#    'Net Income': '2622000000.0',
#    'Net Income - Discontinued ops': '-14000000.0',
#    'Net Income - Non-Controlling int': '73000000.0',
#    'Net Income Com': '2622000000.0',
#    'Net Profit Margin': '0.0854',
#    'Operating Expenses': '13346000000.0',
#    'Operating Income': '4388000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.085',
#    'R&D Expenses': '0.0',
#    'Revenue': '30708000000.0',
#    'Revenue Growth': '-0.000845968634086028',
#    'SG&A Expense': '8445000000.0',
#    'Weighted Average Shs Out': '5901000000.0',
#    'Weighted Average Shs Out (Dil)': '5901000000.0',
#    'date': '2009-12-31'},
#   {'Consolidated Income': '3275000000.0',
#    'Cost of Revenue': '12907000000.0',
#    'Dividend per Share': '0.41',
#    'EBIT': '5506000000.0',
#    'EBIT Margin': '0.1792',
#    'EBITDA': '10387000000.0',
#    'EBITDA Margin': '0.338',
#    'EPS': '0.54',
#    'EPS Diluted': '0.54',
#    'Earnings Before Tax Margin': '0.1515',
#    'Earnings before Tax': '4655000000.0',
#    'Free Cash Flow margin': '0.184',
#    'Gross Margin': '0.58',
#    'Gross Profit': '17827000000.0',
#    'Income Tax Expense': '1463000000.0',
#    'Interest Expense': '851000000.0',
#    'Net Income': '3192000000.0',
#    'Net Income - Discontinued ops': '-7000000.0',
#    'Net Income - Non-Controlling int': '83000000.0',
#    'Net Income Com': '3192000000.0',
#    'Net Profit Margin': '0.1039',
#    'Operating Expenses': '12455000000.0',
#    'Operating Income': '5372000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.104',
#    'R&D Expenses': '0.0',
#    'Revenue': '30734000000.0',
#    'Revenue Growth': '0.00391977526621807',
#    'SG&A Expense': '7574000000.0',
#    'Weighted Average Shs Out': '5900000000.0',
#    'Weighted Average Shs Out (Dil)': '5901000000.0',
#    'date': '2009-09-30'},
#   {'Consolidated Income': '3276000000.0',
#    'Cost of Revenue': '12557000000.0',
#    'Dividend per Share': '0.41',
#    'EBIT': '5686000000.0',
#    'EBIT Margin': '0.1857',
#    'EBITDA': '10533000000.0',
#    'EBITDA Margin': '0.344',
#    'EPS': '0.54',
#    'EPS Diluted': '0.54',
#    'Earnings Before Tax Margin': '0.1571',
#    'Earnings before Tax': '4810000000.0',
#    'Free Cash Flow margin': '0.1311',
#    'Gross Margin': '0.5898',
#    'Gross Profit': '18057000000.0',
#    'Income Tax Expense': '1612000000.0',
#    'Interest Expense': '876000000.0',
#    'Net Income': '3198000000.0',
#    'Net Income - Discontinued ops': '-3000000.0',
#    'Net Income - Non-Controlling int': '78000000.0',
#    'Net Income Com': '3198000000.0',
#    'Net Profit Margin': '0.1045',
#    'Operating Expenses': '12557000000.0',
#    'Operating Income': '5500000000.0',
#    'Preferred Dividends': '0.0',
#    'Profit Margin': '0.104',
#    'R&D Expenses': '0.0',
#    'Revenue': '30614000000.0',
#    'Revenue Growth': '-0.0082',
#    'SG&A Expense': '7682000000.0',
#    'Weighted Average Shs Out': '5900000000.0',
#    'Weighted Average Shs Out (Dil)': '',
#    'date': '2009-06-30'}],
#  'symbol': 'T'}

# %%
# Main ingredients for Return on Equity: Net Income & Book Value
net_income = float(data['financials'][0]['Net Income Com'])
display(f'Net Income = {net_income}')
# Out:
# 'Net Income = 3700000000.0'

# %%
# Total Share Holder Equity
balance_sheet = r.get(f"https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{stock}?period=quarter")
balance_sheet = balance_sheet.json()
balance_sheet
# Out:
# {'financials': [{'Cash and cash equivalents': '6588000000.0',
#    'Cash and short-term investments': '6588000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '1.68166e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.53568e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.58588e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '45141000000.0',
#    'Other comprehensive income': '125222000000',
#    'Payables': '43955000000.0',
#    'Property, Plant & Equipment Net': '1.31316e+11',
#    'Receivables': '22921000000.0',
#    'Retained earnings (deficit)': '59347000000.0',
#    'Short-term debt': '11608000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2741000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '5.48796e+11',
#    'Total current assets': '50695000000.0',
#    'Total current liabilities': '68126000000.0',
#    'Total debt': '1.65176e+11',
#    'Total liabilities': '3.54469e+11',
#    'Total non-current assets': '4.98101e+11',
#    'Total non-current liabilities': '2.41202e+11',
#    'Total shareholders equity': '1.94327e+11',
#    'date': '2019-09-30'},
#   {'Cash and cash equivalents': '8423000000.0',
#    'Cash and short-term investments': '8423000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '1.69946e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.5779e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.62139e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '41778000000.0',
#    'Other comprehensive income': '123782000000',
#    'Payables': '42082000000.0',
#    'Property, Plant & Equipment Net': '1.32074e+11',
#    'Receivables': '22381000000.0',
#    'Retained earnings (deficit)': '59389000000.0',
#    'Short-term debt': '12772000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2062000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '5.46914e+11',
#    'Total current assets': '47218000000.0',
#    'Total current liabilities': '66376000000.0',
#    'Total debt': '1.70562e+11',
#    'Total liabilities': '3.52833e+11',
#    'Total non-current assets': '4.99696e+11',
#    'Total non-current liabilities': '2.44679e+11',
#    'Total shareholders equity': '1.94081e+11',
#    'date': '2019-06-30'},
#   {'Cash and cash equivalents': '6516000000.0',
#    'Cash and short-term investments': '6516000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '1.71166e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.63942e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.68964e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '37917000000.0',
#    'Other comprehensive income': '123561000000',
#    'Payables': '42306000000.0',
#    'Property, Plant & Equipment Net': '1.32051e+11',
#    'Receivables': '23863000000.0',
#    'Retained earnings (deficit)': '59424000000.0',
#    'Short-term debt': '11538000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1130000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '5.48384e+11',
#    'Total current assets': '46472000000.0',
#    'Total current liabilities': '64652000000.0',
#    'Total debt': '1.7548e+11',
#    'Total liabilities': '3.53433e+11',
#    'Total non-current assets': '5.01912e+11',
#    'Total non-current liabilities': '2.50864e+11',
#    'Total shareholders equity': '1.94951e+11',
#    'date': '2019-03-31'},
#   {'Cash and cash equivalents': '5204000000.0',
#    'Cash and short-term investments': '5204000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '5948000000.0',
#    'Goodwill and Intangible Assets': '1.72639e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.6625e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.71301e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '19218000000.0',
#    'Other comprehensive income': '123261000000',
#    'Payables': '43184000000.0',
#    'Property, Plant & Equipment Net': '1.31473e+11',
#    'Receivables': '26472000000.0',
#    'Retained earnings (deficit)': '58753000000.0',
#    'Short-term debt': '10255000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1179000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '5.31864e+11',
#    'Total current assets': '51427000000.0',
#    'Total current liabilities': '64420000000.0',
#    'Total debt': '1.76505e+11',
#    'Total liabilities': '3.3798e+11',
#    'Total non-current assets': '4.80437e+11',
#    'Total non-current liabilities': '2.54342e+11',
#    'Total shareholders equity': '1.93884e+11',
#    'date': '2018-12-31'},
#   {'Cash and cash equivalents': '8657000000.0',
#    'Cash and short-term investments': '8657000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '6045000000.0',
#    'Goodwill and Intangible Assets': '1.63437e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.68513e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.74761e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '28981000000.0',
#    'Other comprehensive income': '114343000000',
#    'Payables': '39375000000.0',
#    'Property, Plant & Equipment Net': '1.30348e+11',
#    'Receivables': '26312000000.0',
#    'Retained earnings (deficit)': '57624000000.0',
#    'Short-term debt': '14905000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1460000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '5.3487e+11',
#    'Total current assets': '53107000000.0',
#    'Total current liabilities': '65420000000.0',
#    'Total debt': '1.83418e+11',
#    'Total liabilities': '3.49899e+11',
#    'Total non-current assets': '4.81763e+11',
#    'Total non-current liabilities': '2.55498e+11',
#    'Total shareholders equity': '1.84971e+11',
#    'date': '2018-09-30'},
#   {'Cash and cash equivalents': '13523000000.0',
#    'Cash and short-term investments': '13523000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '5914000000.0',
#    'Goodwill and Intangible Assets': '1.6001e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.68495e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.76644e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '28791000000.0',
#    'Other comprehensive income': '114238000000',
#    'Payables': '35488000000.0',
#    'Property, Plant & Equipment Net': '1.29556e+11',
#    'Receivables': '25492000000.0',
#    'Retained earnings (deficit)': '56555000000.0',
#    'Short-term debt': '21672000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1889000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '5.34691e+11',
#    'Total current assets': '55286000000.0',
#    'Total current liabilities': '68593000000.0',
#    'Total debt': '1.90167e+11',
#    'Total liabilities': '3.50561e+11',
#    'Total non-current assets': '4.79405e+11',
#    'Total non-current liabilities': '2.53177e+11',
#    'Total shareholders equity': '1.8413e+11',
#    'date': '2018-06-30'},
#   {'Cash and cash equivalents': '48872000000.0',
#    'Cash and short-term investments': '48872000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '5081000000.0',
#    'Goodwill and Intangible Assets': '1.12683e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.33724e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.14174e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '30116000000.0',
#    'Other comprehensive income': '78128000000',
#    'Payables': '31569000000.0',
#    'Property, Plant & Equipment Net': '1.25124e+11',
#    'Receivables': '16290000000.0',
#    'Retained earnings (deficit)': '55067000000.0',
#    'Short-term debt': '29322000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1534000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.46343e+11',
#    'Total current assets': '78505000000.0',
#    'Total current liabilities': '70580000000.0',
#    'Total debt': '1.63046e+11',
#    'Total liabilities': '2.99267e+11',
#    'Total non-current assets': '3.67838e+11',
#    'Total non-current liabilities': '1.98571e+11',
#    'Total shareholders equity': '1.47076e+11',
#    'date': '2018-03-31'},
#   {'Cash and cash equivalents': '50498000000.0',
#    'Cash and short-term investments': '50498000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4213000000.0',
#    'Goodwill and Intangible Assets': '1.12913e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.25972e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.13848e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '31775000000.0',
#    'Other comprehensive income': '77995000000',
#    'Payables': '34470000000.0',
#    'Property, Plant & Equipment Net': '1.25222e+11',
#    'Receivables': '16522000000.0',
#    'Retained earnings (deficit)': '50500000000.0',
#    'Short-term debt': '38374000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1262000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.44097e+11',
#    'Total current assets': '79146000000.0',
#    'Total current liabilities': '81389000000.0',
#    'Total debt': '1.64346e+11',
#    'Total liabilities': '3.0209e+11',
#    'Total non-current assets': '3.64951e+11',
#    'Total non-current liabilities': '1.88926e+11',
#    'Total shareholders equity': '1.42007e+11',
#    'date': '2017-12-31'},
#   {'Cash and cash equivalents': '48499000000.0',
#    'Cash and short-term investments': '48499000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4503000000.0',
#    'Goodwill and Intangible Assets': '1.13443e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.54728e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.1478e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '31231000000.0',
#    'Other comprehensive income': '77960000000',
#    'Payables': '28928000000.0',
#    'Property, Plant & Equipment Net': '1.26462e+11',
#    'Receivables': '15876000000.0',
#    'Retained earnings (deficit)': '36074000000.0',
#    'Short-term debt': '8551000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2703000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.43865e+11',
#    'Total current assets': '76357000000.0',
#    'Total current liabilities': '47693000000.0',
#    'Total debt': '1.63279e+11',
#    'Total liabilities': '3.17756e+11',
#    'Total non-current assets': '3.67508e+11',
#    'Total non-current liabilities': '2.38832e+11',
#    'Total shareholders equity': '1.26109e+11',
#    'date': '2017-09-30'},
#   {'Cash and cash equivalents': '25617000000.0',
#    'Cash and short-term investments': '25617000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4371000000.0',
#    'Goodwill and Intangible Assets': '1.13526e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.32824e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.18038e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '31422000000.0',
#    'Other comprehensive income': '77907000000',
#    'Payables': '26471000000.0',
#    'Property, Plant & Equipment Net': '1.26184e+11',
#    'Receivables': '14997000000.0',
#    'Retained earnings (deficit)': '36067000000.0',
#    'Short-term debt': '10831000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '3331000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.20795e+11',
#    'Total current assets': '53547000000.0',
#    'Total current liabilities': '48012000000.0',
#    'Total debt': '1.43655e+11',
#    'Total liabilities': '2.94937e+11',
#    'Total non-current assets': '3.67248e+11',
#    'Total non-current liabilities': '2.15503e+11',
#    'Total shareholders equity': '1.25858e+11',
#    'date': '2017-06-30'},
#   {'Cash and cash equivalents': '14884000000.0',
#    'Cash and short-term investments': '14884000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4493000000.0',
#    'Goodwill and Intangible Assets': '1.13888e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.20568e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.18365e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '33404000000.0',
#    'Other comprehensive income': '78151000000',
#    'Payables': '27120000000.0',
#    'Property, Plant & Equipment Net': '1.25292e+11',
#    'Receivables': '15078000000.0',
#    'Retained earnings (deficit)': '35175000000.0',
#    'Short-term debt': '12681000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '3384000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.11903e+11',
#    'Total current assets': '45727000000.0',
#    'Total current liabilities': '50690000000.0',
#    'Total debt': '1.33249e+11',
#    'Total liabilities': '2.86922e+11',
#    'Total non-current assets': '3.66176e+11',
#    'Total non-current liabilities': '2.02828e+11',
#    'Total shareholders equity': '1.24981e+11',
#    'date': '2017-03-31'},
#   {'Cash and cash equivalents': '5788000000.0',
#    'Cash and short-term investments': '5788000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4519000000.0',
#    'Goodwill and Intangible Assets': '1.13648e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.13681e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.17725e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '33578000000.0',
#    'Other comprehensive income': '77920000000',
#    'Payables': '31138000000.0',
#    'Property, Plant & Equipment Net': '1.24899e+11',
#    'Receivables': '16794000000.0',
#    'Retained earnings (deficit)': '34734000000.0',
#    'Short-term debt': '9832000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2079000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.03821e+11',
#    'Total current assets': '38369000000.0',
#    'Total current liabilities': '50576000000.0',
#    'Total debt': '1.23513e+11',
#    'Total liabilities': '2.79711e+11',
#    'Total non-current assets': '3.65452e+11',
#    'Total non-current liabilities': '1.95557e+11',
#    'Total shareholders equity': '1.2411e+11',
#    'date': '2016-12-31'},
#   {'Cash and cash equivalents': '5895000000.0',
#    'Cash and short-term investments': '5895000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4637000000.0',
#    'Goodwill and Intangible Assets': '1.14005e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.17239e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.19326e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '33483000000.0',
#    'Other comprehensive income': '77939000000',
#    'Payables': '28849000000.0',
#    'Property, Plant & Equipment Net': '1.23922e+11',
#    'Receivables': '16855000000.0',
#    'Retained earnings (deficit)': '35319000000.0',
#    'Short-term debt': '7982000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2686000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.02975e+11',
#    'Total current assets': '37374000000.0',
#    'Total current liabilities': '47102000000.0',
#    'Total debt': '1.25221e+11',
#    'Total liabilities': '2.78372e+11',
#    'Total non-current assets': '3.65601e+11',
#    'Total non-current liabilities': '1.97787e+11',
#    'Total shareholders equity': '1.24603e+11',
#    'date': '2016-09-30'},
#   {'Cash and cash equivalents': '7208000000.0',
#    'Cash and short-term investments': '7208000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4465000000.0',
#    'Goodwill and Intangible Assets': '1.14359e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.17308e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.19628e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '34023000000.0',
#    'Other comprehensive income': '78112000000',
#    'Payables': '26746000000.0',
#    'Property, Plant & Equipment Net': '1.23537e+11',
#    'Receivables': '15830000000.0',
#    'Retained earnings (deficit)': '34950000000.0',
#    'Short-term debt': '9528000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2773000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.01808e+11',
#    'Total current assets': '36005000000.0',
#    'Total current liabilities': '46465000000.0',
#    'Total debt': '1.26836e+11',
#    'Total liabilities': '2.77437e+11',
#    'Total non-current assets': '3.65803e+11',
#    'Total non-current liabilities': '1.96949e+11',
#    'Total shareholders equity': '1.24371e+11',
#    'date': '2016-06-30'},
#   {'Cash and cash equivalents': '10008000000.0',
#    'Cash and short-term investments': '10008000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4550000000.0',
#    'Goodwill and Intangible Assets': '1.13759e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.22104e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.20495e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '34114000000.0',
#    'Other comprehensive income': '78224000000',
#    'Payables': '26169000000.0',
#    'Property, Plant & Equipment Net': '1.23454e+11',
#    'Receivables': '16070000000.0',
#    'Retained earnings (deficit)': '34506000000.0',
#    'Short-term debt': '8399000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2455000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.03638e+11',
#    'Total current assets': '38001000000.0',
#    'Total current liabilities': '44528000000.0',
#    'Total debt': '1.30503e+11',
#    'Total liabilities': '2.79233e+11',
#    'Total non-current assets': '3.65637e+11',
#    'Total non-current liabilities': '2.00591e+11',
#    'Total shareholders equity': '1.24405e+11',
#    'date': '2016-03-31'},
#   {'Cash and cash equivalents': '5121000000.0',
#    'Cash and short-term investments': '5121000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4682000000.0',
#    'Goodwill and Intangible Assets': '1.13977e+11',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.18515e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '1.2103e+11',
#    'Other Assets': '0.0',
#    'Other Liabilities': '34262000000.0',
#    'Other comprehensive income': '78140000000',
#    'Payables': '30372000000.0',
#    'Property, Plant & Equipment Net': '1.2445e+11',
#    'Receivables': '16532000000.0',
#    'Retained earnings (deficit)': '33671000000.0',
#    'Short-term debt': '7636000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2176000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '4.02672e+11',
#    'Total current assets': '35992000000.0',
#    'Total current liabilities': '47816000000.0',
#    'Total debt': '1.26151e+11',
#    'Total liabilities': '2.79032e+11',
#    'Total non-current assets': '3.6668e+11',
#    'Total non-current liabilities': '1.96954e+11',
#    'Total shareholders equity': '1.2364e+11',
#    'date': '2015-12-31'},
#   {'Cash and cash equivalents': '0.0',
#    'Cash and short-term investments': '0.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '0.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '0.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '0.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '0.0',
#    'Other comprehensive income': '0.0',
#    'Payables': '0.0',
#    'Property, Plant & Equipment Net': '0.0',
#    'Receivables': '0.0',
#    'Retained earnings (deficit)': '0.0',
#    'Short-term debt': '0.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '0.0',
#    'Tax assets': '0.0',
#    'Total assets': '0.0',
#    'Total current assets': '0.0',
#    'Total current liabilities': '0.0',
#    'Total debt': '0.0',
#    'Total liabilities': '0.0',
#    'Total non-current assets': '0.0',
#    'Total non-current liabilities': '0.0',
#    'Total shareholders equity': '0.0',
#    'date': '2015-10-28'},
#   {'Cash and cash equivalents': '6202000000.0',
#    'Cash and short-term investments': '6202000000.0',
#    'Deferred revenue': '4640000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '226873000000.0',
#    'Inventories': '0.0',
#    'Investments': '1744000000.0',
#    'Long-term debt': '119395000000.0',
#    'Long-term investments': '1744000000.0',
#    'Net Debt': '120728000000.0',
#    'Other Assets': '12420000000.0',
#    'Other Liabilities': '12123000000.0',
#    'Other comprehensive income': '5294000000.0',
#    'Payables': '28280000000.0',
#    'Property, Plant & Equipment Net': '122836000000.0',
#    'Receivables': '16329000000.0',
#    'Retained earnings (deficit)': '32627000000.0',
#    'Short-term debt': '7535000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '57635000000.0',
#    'Tax assets': '0.0',
#    'Total assets': '399989000000.0',
#    'Total current assets': '34951000000.0',
#    'Total current liabilities': '47938000000.0',
#    'Total debt': '126930000000.0',
#    'Total liabilities': '277200000000.0',
#    'Total non-current assets': '365038000000.0',
#    'Total non-current liabilities': '229262000000.0',
#    'Total shareholders equity': '121824000000.0',
#    'date': '2015-09-30'},
#   {'Cash and cash equivalents': '20956000000.0',
#    'Cash and short-term investments': '20956000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4075000000.0',
#    'Goodwill and Intangible Assets': '77305000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '1.05067e+11',
#    'Long-term investments': '0.0',
#    'Net Debt': '92714000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.1367e+11',
#    'Other comprehensive income': '44881000000',
#    'Payables': '21560000000.0',
#    'Property, Plant & Equipment Net': '1.14348e+11',
#    'Receivables': '13821000000.0',
#    'Retained earnings (deficit)': '29086000000.0',
#    'Short-term debt': '8603000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '3848000000.0',
#    'Tax assets': '1131000000.0',
#    'Total assets': '3.26489e+11',
#    'Total current assets': '43163000000.0',
#    'Total current liabilities': '40527000000.0',
#    'Total debt': '1.1367e+11',
#    'Total liabilities': '2.38988e+11',
#    'Total non-current assets': '2.83326e+11',
#    'Total non-current liabilities': '84791000000.0',
#    'Total shareholders equity': '87501000000.0',
#    'date': '2015-06-30'},
#   {'Cash and cash equivalents': '4444000000.0',
#    'Cash and short-term investments': '4444000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4221000000.0',
#    'Goodwill and Intangible Assets': '76764000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '88272000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '92009000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.13112e+11',
#    'Other comprehensive income': '44778000000',
#    'Payables': '20418000000.0',
#    'Property, Plant & Equipment Net': '1.13198e+11',
#    'Receivables': '13592000000.0',
#    'Retained earnings (deficit)': '28490000000.0',
#    'Short-term debt': '8181000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2390000000.0',
#    'Tax assets': '1538000000.0',
#    'Total assets': '3.08028e+11',
#    'Total current assets': '27410000000.0',
#    'Total current liabilities': '37651000000.0',
#    'Total debt': '96453000000.0',
#    'Total liabilities': '2.20924e+11',
#    'Total non-current assets': '2.80618e+11',
#    'Total non-current liabilities': '70161000000.0',
#    'Total shareholders equity': '87104000000.0',
#    'date': '2015-03-31'},
#   {'Cash and cash equivalents': '8603000000.0',
#    'Cash and short-term investments': '8603000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4105000000.0',
#    'Goodwill and Intangible Assets': '75831000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '76011000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '73464000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.12167e+11',
#    'Other comprehensive income': '44633000000',
#    'Payables': '23592000000.0',
#    'Property, Plant & Equipment Net': '1.12898e+11',
#    'Receivables': '14527000000.0',
#    'Retained earnings (deficit)': '27736000000.0',
#    'Short-term debt': '6056000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1091000000.0',
#    'Tax assets': '1142000000.0',
#    'Total assets': '2.92829e+11',
#    'Total current assets': '32028000000.0',
#    'Total current liabilities': '37282000000.0',
#    'Total debt': '82067000000.0',
#    'Total liabilities': '2.05905e+11',
#    'Total non-current assets': '2.60801e+11',
#    'Total non-current liabilities': '56456000000.0',
#    'Total shareholders equity': '86924000000.0',
#    'date': '2014-12-31'},
#   {'Cash and cash equivalents': '2458000000.0',
#    'Cash and short-term investments': '2458000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4038000000.0',
#    'Goodwill and Intangible Assets': '76383000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '70516000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '73167000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.04704e+11',
#    'Other comprehensive income': '44533000000',
#    'Payables': '24119000000.0',
#    'Property, Plant & Equipment Net': '1.15134e+11',
#    'Receivables': '13445000000.0',
#    'Retained earnings (deficit)': '34165000000.0',
#    'Short-term debt': '5109000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '4328000000.0',
#    'Tax assets': '1030000000.0',
#    'Total assets': '2.87939e+11',
#    'Total current assets': '25835000000.0',
#    'Total current liabilities': '39979000000.0',
#    'Total debt': '75625000000.0',
#    'Total liabilities': '1.9482e+11',
#    'Total non-current assets': '2.62104e+11',
#    'Total non-current liabilities': '50137000000.0',
#    'Total shareholders equity': '93119000000.0',
#    'date': '2014-09-30'},
#   {'Cash and cash equivalents': '11305000000.0',
#    'Cash and short-term investments': '11305000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3990000000.0',
#    'Goodwill and Intangible Assets': '76474000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '73570000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '72747000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.0374e+11',
#    'Other comprehensive income': '44725000000',
#    'Payables': '22966000000.0',
#    'Property, Plant & Equipment Net': '1.1436e+11',
#    'Receivables': '13001000000.0',
#    'Retained earnings (deficit)': '33554000000.0',
#    'Short-term debt': '10482000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '3962000000.0',
#    'Tax assets': '1180000000.0',
#    'Total assets': '2.93466e+11',
#    'Total current assets': '33112000000.0',
#    'Total current liabilities': '43788000000.0',
#    'Total debt': '84052000000.0',
#    'Total liabilities': '2.00841e+11',
#    'Total non-current assets': '2.60354e+11',
#    'Total non-current liabilities': '53313000000.0',
#    'Total shareholders equity': '92625000000.0',
#    'date': '2014-06-30'},
#   {'Cash and cash equivalents': '3611000000.0',
#    'Cash and short-term investments': '3611000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4121000000.0',
#    'Goodwill and Intangible Assets': '76235000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '71575000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '76265000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.02925e+11',
#    'Other comprehensive income': '44806000000',
#    'Payables': '22234000000.0',
#    'Property, Plant & Equipment Net': '1.12809e+11',
#    'Receivables': '13120000000.0',
#    'Retained earnings (deficit)': '32402000000.0',
#    'Short-term debt': '8301000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2784000000.0',
#    'Tax assets': '1171000000.0',
#    'Total assets': '2.8534e+11',
#    'Total current assets': '24089000000.0',
#    'Total current liabilities': '39830000000.0',
#    'Total debt': '79876000000.0',
#    'Total liabilities': '1.93971e+11',
#    'Total non-current assets': '2.61251e+11',
#    'Total non-current liabilities': '51216000000.0',
#    'Total shareholders equity': '91369000000.0',
#    'date': '2014-03-31'},
#   {'Cash and cash equivalents': '3339000000.0',
#    'Cash and short-term investments': '3339000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4212000000.0',
#    'Goodwill and Intangible Assets': '74289000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '69290000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '71449000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.02562e+11',
#    'Other comprehensive income': '45966000000',
#    'Payables': '21107000000.0',
#    'Property, Plant & Equipment Net': '1.10968e+11',
#    'Receivables': '12918000000.0',
#    'Retained earnings (deficit)': '31141000000.0',
#    'Short-term debt': '5498000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1774000000.0',
#    'Tax assets': '1199000000.0',
#    'Total assets': '2.77787e+11',
#    'Total current assets': '23196000000.0',
#    'Total current liabilities': '34995000000.0',
#    'Total debt': '74788000000.0',
#    'Total liabilities': '1.86305e+11',
#    'Total non-current assets': '2.54591e+11',
#    'Total non-current liabilities': '48748000000.0',
#    'Total shareholders equity': '91482000000.0',
#    'date': '2013-12-31'},
#   {'Cash and cash equivalents': '1371000000.0',
#    'Cash and short-term investments': '1371000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4013000000.0',
#    'Goodwill and Intangible Assets': '75034000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '68350000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '74852000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.03368e+11',
#    'Other comprehensive income': '47705000000',
#    'Payables': '20433000000.0',
#    'Property, Plant & Equipment Net': '1.12424e+11',
#    'Receivables': '12444000000.0',
#    'Retained earnings (deficit)': '26648000000.0',
#    'Short-term debt': '7873000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1488000000.0',
#    'Tax assets': '682000000.0',
#    'Total assets': '2.74599e+11',
#    'Total current assets': '18435000000.0',
#    'Total current liabilities': '36183000000.0',
#    'Total debt': '76223000000.0',
#    'Total liabilities': '1.88469e+11',
#    'Total non-current assets': '2.56164e+11',
#    'Total non-current liabilities': '48918000000.0',
#    'Total shareholders equity': '86130000000.0',
#    'date': '2013-09-30'},
#   {'Cash and cash equivalents': '4548000000.0',
#    'Cash and short-term investments': '4548000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4029000000.0',
#    'Goodwill and Intangible Assets': '74788000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '71917000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '70625000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '1.00794e+11',
#    'Other comprehensive income': '49501000000',
#    'Payables': '19438000000.0',
#    'Property, Plant & Equipment Net': '1.10734e+11',
#    'Receivables': '12508000000.0',
#    'Retained earnings (deficit)': '25212000000.0',
#    'Short-term debt': '3256000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2065000000.0',
#    'Tax assets': '953000000.0',
#    'Total assets': '2.72093e+11',
#    'Total current assets': '21428000000.0',
#    'Total current liabilities': '31189000000.0',
#    'Total debt': '75173000000.0',
#    'Total liabilities': '1.85778e+11',
#    'Total non-current assets': '2.50665e+11',
#    'Total non-current liabilities': '53795000000.0',
#    'Total shareholders equity': '86315000000.0',
#    'date': '2013-06-30'},
#   {'Cash and cash equivalents': '3875000000.0',
#    'Cash and short-term investments': '3875000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '4167000000.0',
#    'Goodwill and Intangible Assets': '74794000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '70686000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '70257000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '99499000000.0',
#    'Other comprehensive income': '52712000000',
#    'Payables': '17523000000.0',
#    'Property, Plant & Equipment Net': '1.09702e+11',
#    'Receivables': '12100000000.0',
#    'Retained earnings (deficit)': '23787000000.0',
#    'Short-term debt': '3446000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2210000000.0',
#    'Tax assets': '980000000.0',
#    'Total assets': '2.70994e+11',
#    'Total current assets': '20372000000.0',
#    'Total current liabilities': '29786000000.0',
#    'Total debt': '74132000000.0',
#    'Total liabilities': '1.82656e+11',
#    'Total non-current assets': '2.50622e+11',
#    'Total non-current liabilities': '53371000000.0',
#    'Total shareholders equity': '88338000000.0',
#    'date': '2013-03-31'},
#   {'Cash and cash equivalents': '4868000000.0',
#    'Cash and short-term investments': '4868000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3808000000.0',
#    'Goodwill and Intangible Assets': '74805000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '66358000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '64976000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '98374000000.0',
#    'Other comprehensive income': '58483000000',
#    'Payables': '20911000000.0',
#    'Property, Plant & Equipment Net': '1.09767e+11',
#    'Receivables': '12657000000.0',
#    'Retained earnings (deficit)': '22481000000.0',
#    'Short-term debt': '3486000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1026000000.0',
#    'Tax assets': '1036000000.0',
#    'Total assets': '2.72315e+11',
#    'Total current assets': '22706000000.0',
#    'Total current liabilities': '31787000000.0',
#    'Total debt': '69844000000.0',
#    'Total liabilities': '1.7962e+11',
#    'Total non-current assets': '2.49609e+11',
#    'Total non-current liabilities': '49459000000.0',
#    'Total shareholders equity': '92695000000.0',
#    'date': '2012-12-31'},
#   {'Cash and cash equivalents': '2217000000.0',
#    'Cash and short-term investments': '2217000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3709000000.0',
#    'Goodwill and Intangible Assets': '74800000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '60314000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '61530000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '60314000000.0',
#    'Other comprehensive income': '62766000000',
#    'Payables': '18936000000.0',
#    'Property, Plant & Equipment Net': '1.08217e+11',
#    'Receivables': '12398000000.0',
#    'Retained earnings (deficit)': '28907000000.0',
#    'Short-term debt': '3433000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '2209000000.0',
#    'Tax assets': '1312000000.0',
#    'Total assets': '2.66849e+11',
#    'Total current assets': '18958000000.0',
#    'Total current liabilities': '30798000000.0',
#    'Total debt': '63747000000.0',
#    'Total liabilities': '1.65575e+11',
#    'Total non-current assets': '2.47891e+11',
#    'Total non-current liabilities': '74463000000.0',
#    'Total shareholders equity': '1.01274e+11',
#    'date': '2012-09-30'},
#   {'Cash and cash equivalents': '2151000000.0',
#    'Cash and short-term investments': '2151000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3743000000.0',
#    'Goodwill and Intangible Assets': '74808000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '61132000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '62383000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '61132000000.0',
#    'Other comprehensive income': '66357000000',
#    'Payables': '16298000000.0',
#    'Property, Plant & Equipment Net': '1.07483e+11',
#    'Receivables': '12430000000.0',
#    'Retained earnings (deficit)': '27788000000.0',
#    'Short-term debt': '3402000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '3705000000.0',
#    'Tax assets': '1418000000.0',
#    'Total assets': '2.66294e+11',
#    'Total current assets': '19156000000.0',
#    'Total current liabilities': '29702000000.0',
#    'Total debt': '64534000000.0',
#    'Total liabilities': '1.62715e+11',
#    'Total non-current assets': '2.47138e+11',
#    'Total non-current liabilities': '71881000000.0',
#    'Total shareholders equity': '1.03579e+11',
#    'date': '2012-06-30'},
#   {'Cash and cash equivalents': '2442000000.0',
#    'Cash and short-term investments': '2442000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3966000000.0',
#    'Goodwill and Intangible Assets': '76132000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '58934000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '63267000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '58934000000.0',
#    'Other comprehensive income': '68860000000',
#    'Payables': '17593000000.0',
#    'Property, Plant & Equipment Net': '1.07231e+11',
#    'Receivables': '13167000000.0',
#    'Retained earnings (deficit)': '26446000000.0',
#    'Short-term debt': '6775000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1601000000.0',
#    'Tax assets': '1463000000.0',
#    'Total assets': '2.69356e+11',
#    'Total current assets': '20765000000.0',
#    'Total current liabilities': '32520000000.0',
#    'Total debt': '65709000000.0',
#    'Total liabilities': '1.64169e+11',
#    'Total non-current assets': '2.48591e+11',
#    'Total non-current liabilities': '72715000000.0',
#    'Total shareholders equity': '1.05187e+11',
#    'date': '2012-03-31'},
#   {'Cash and cash equivalents': '3185000000.0',
#    'Cash and short-term investments': '3185000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3872000000.0',
#    'Goodwill and Intangible Assets': '76054000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '61300000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '61568000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '61300000000.0',
#    'Other comprehensive income': '70669000000',
#    'Payables': '19858000000.0',
#    'Property, Plant & Equipment Net': '1.07087e+11',
#    'Receivables': '13606000000.0',
#    'Retained earnings (deficit)': '25453000000.0',
#    'Short-term debt': '3453000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1003000000.0',
#    'Tax assets': '1470000000.0',
#    'Total assets': '2.70344e+11',
#    'Total current assets': '23027000000.0',
#    'Total current liabilities': '30794000000.0',
#    'Total debt': '64753000000.0',
#    'Total liabilities': '1.64547e+11',
#    'Total non-current assets': '2.47317e+11',
#    'Total non-current liabilities': '72453000000.0',
#    'Total shareholders equity': '1.05797e+11',
#    'date': '2011-12-31'},
#   {'Cash and cash equivalents': '10762000000.0',
#    'Cash and short-term investments': '10762000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3794000000.0',
#    'Goodwill and Intangible Assets': '78984000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '62326000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '60464000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '62326000000.0',
#    'Other comprehensive income': '70952000000',
#    'Payables': '17860000000.0',
#    'Property, Plant & Equipment Net': '1.05786e+11',
#    'Receivables': '13377000000.0',
#    'Retained earnings (deficit)': '34758000000.0',
#    'Short-term debt': '8900000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '929000000.0',
#    'Tax assets': '1101000000.0',
#    'Total assets': '2.77653e+11',
#    'Total current assets': '28605000000.0',
#    'Total current liabilities': '34031000000.0',
#    'Total debt': '71226000000.0',
#    'Total liabilities': '1.63771e+11',
#    'Total non-current assets': '2.49048e+11',
#    'Total non-current liabilities': '67414000000.0',
#    'Total shareholders equity': '1.13882e+11',
#    'date': '2011-09-30'},
#   {'Cash and cash equivalents': '3831000000.0',
#    'Cash and short-term investments': '3831000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3804000000.0',
#    'Goodwill and Intangible Assets': '78998000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '58663000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '62742000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '58663000000.0',
#    'Other comprehensive income': '71207000000',
#    'Payables': '18145000000.0',
#    'Property, Plant & Equipment Net': '1.04606e+11',
#    'Receivables': '13608000000.0',
#    'Retained earnings (deficit)': '33687000000.0',
#    'Short-term debt': '7910000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1130000000.0',
#    'Tax assets': '1180000000.0',
#    'Total assets': '2.72014e+11',
#    'Total current assets': '22239000000.0',
#    'Total current liabilities': '33537000000.0',
#    'Total debt': '66573000000.0',
#    'Total liabilities': '1.57905e+11',
#    'Total non-current assets': '2.49775e+11',
#    'Total non-current liabilities': '65705000000.0',
#    'Total shareholders equity': '1.14109e+11',
#    'date': '2011-06-30'},
#   {'Cash and cash equivalents': '1391000000.0',
#    'Cash and short-term investments': '1391000000.0',
#    'Deferred revenue': '0.0',
#    'Deposit Liabilities': '3959000000.0',
#    'Goodwill and Intangible Assets': '79025000000.0',
#    'Inventories': '0.0',
#    'Investments': '0.0',
#    'Long-term debt': '58126000000.0',
#    'Long-term investments': '0.0',
#    'Net Debt': '63637000000.0',
#    'Other Assets': '0.0',
#    'Other Liabilities': '58126000000.0',
#    'Other comprehensive income': '70986000000',
#    'Payables': '18349000000.0',
#    'Property, Plant & Equipment Net': '1.03369e+11',
#    'Receivables': '13246000000.0',
#    'Retained earnings (deficit)': '32649000000.0',
#    'Short-term debt': '6902000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '1499000000.0',
#    'Tax assets': '1157000000.0',
#    'Total assets': '2.68085e+11',
#    'Total current assets': '19737000000.0',
#    'Total current liabilities': '33254000000.0',
#    'Total debt': '65028000000.0',
#    'Total liabilities': '1.55242e+11',
#    'Total non-current assets': '2.48348e+11',
#    'Total non-current liabilities': '63862000000.0',
#    'Total shareholders equity': '1.12843e+11',
#    'date': '2011-03-31'},
#   {'Cash and cash equivalents': '1437000000.0',
#    'Cash and short-term investments': '1437000000.0',
#    'Deferred revenue': '4086000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '134121000000.0',
#    'Inventories': '0.0',
#    'Investments': '4515000000.0',
#    'Long-term debt': '58971000000.0',
#    'Long-term investments': '4515000000.0',
#    'Net Debt': '64730000000.0',
#    'Other Assets': '5807000000.0',
#    'Other Liabilities': '7603000000.0',
#    'Other comprehensive income': '2712000000.0',
#    'Payables': '20055000000.0',
#    'Property, Plant & Equipment Net': '103196000000.0',
#    'Receivables': '13610000000.0',
#    'Retained earnings (deficit)': '31792000000.0',
#    'Short-term debt': '7196000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '23045000000.0',
#    'Tax assets': '1170000000.0',
#    'Total assets': '269391000000.0',
#    'Total current assets': '20854000000.0',
#    'Total current liabilities': '34854000000.0',
#    'Total debt': '66167000000.0',
#    'Total liabilities': '157441000000.0',
#    'Total non-current assets': '248537000000.0',
#    'Total non-current liabilities': '122587000000.0',
#    'Total shareholders equity': '111647000000.0',
#    'date': '2010-12-31'},
#   {'Cash and cash equivalents': '3246000000.0',
#    'Cash and short-term investments': '3246000000.0',
#    'Deferred revenue': '3933000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '134454000000.0',
#    'Inventories': '0.0',
#    'Investments': '4544000000.0',
#    'Long-term debt': '62540000000.0',
#    'Long-term investments': '4544000000.0',
#    'Net Debt': '65720000000.0',
#    'Other Assets': '5125000000.0',
#    'Other Liabilities': '7831000000.0',
#    'Other comprehensive income': '-14888000000.0',
#    'Payables': '18417000000.0',
#    'Property, Plant & Equipment Net': '101475000000.0',
#    'Receivables': '13606000000.0',
#    'Retained earnings (deficit)': '50751000000.0',
#    'Short-term debt': '6426000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '22067000000.0',
#    'Tax assets': '1059000000.0',
#    'Total assets': '269252000000.0',
#    'Total current assets': '21977000000.0',
#    'Total current liabilities': '32674000000.0',
#    'Total debt': '68966000000.0',
#    'Total liabilities': '155959000000.0',
#    'Total non-current assets': '247275000000.0',
#    'Total non-current liabilities': '123285000000.0',
#    'Total shareholders equity': '112994000000.0',
#    'date': '2010-09-30'},
#   {'Cash and cash equivalents': '1377000000.0',
#    'Cash and short-term investments': '1377000000.0',
#    'Deferred revenue': '3943000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '135027000000.0',
#    'Inventories': '0.0',
#    'Investments': '4346000000.0',
#    'Long-term debt': '60277000000.0',
#    'Long-term investments': '4346000000.0',
#    'Net Debt': '68621000000.0',
#    'Other Assets': '6235000000.0',
#    'Other Liabilities': '8304000000.0',
#    'Other comprehensive income': '-14852000000.0',
#    'Payables': '18157000000.0',
#    'Property, Plant & Equipment Net': '100302000000.0',
#    'Receivables': '13780000000.0',
#    'Retained earnings (deficit)': '40909000000.0',
#    'Short-term debt': '9721000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '27494000000.0',
#    'Tax assets': '1225000000.0',
#    'Total assets': '267556000000.0',
#    'Total current assets': '21392000000.0',
#    'Total current liabilities': '36182000000.0',
#    'Total debt': '69998000000.0',
#    'Total liabilities': '164073000000.0',
#    'Total non-current assets': '246164000000.0',
#    'Total non-current liabilities': '127891000000.0',
#    'Total shareholders equity': '103046000000.0',
#    'date': '2010-06-30'},
#   {'Cash and cash equivalents': '2617000000.0',
#    'Cash and short-term investments': '2617000000.0',
#    'Deferred revenue': '4061000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '134384000000.0',
#    'Inventories': '0.0',
#    'Investments': '3278000000.0',
#    'Long-term debt': '60024000000.0',
#    'Long-term investments': '3278000000.0',
#    'Net Debt': '66844000000.0',
#    'Other Assets': '5578000000.0',
#    'Other Liabilities': '9182000000.0',
#    'Other comprehensive income': '-14265000000.0',
#    'Payables': '18087000000.0',
#    'Property, Plant & Equipment Net': '99360000000.0',
#    'Receivables': '14167000000.0',
#    'Retained earnings (deficit)': '39373000000.0',
#    'Short-term debt': '9437000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '28159000000.0',
#    'Tax assets': '1293000000.0',
#    'Total assets': '265701000000.0',
#    'Total current assets': '22362000000.0',
#    'Total current liabilities': '36706000000.0',
#    'Total debt': '69461000000.0',
#    'Total liabilities': '163235000000.0',
#    'Total non-current assets': '243339000000.0',
#    'Total non-current liabilities': '126529000000.0',
#    'Total shareholders equity': '102023000000.0',
#    'date': '2010-03-31'},
#   {'Cash and cash equivalents': '3741000000.0',
#    'Cash and short-term investments': '3741000000.0',
#    'Deferred revenue': '4170000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '134410000000.0',
#    'Inventories': '0.0',
#    'Investments': '2921000000.0',
#    'Long-term debt': '64720000000.0',
#    'Long-term investments': '2921000000.0',
#    'Net Debt': '68340000000.0',
#    'Other Assets': '6601000000.0',
#    'Other Liabilities': '8330000000.0',
#    'Other comprehensive income': '2678000000.0',
#    'Payables': '21260000000.0',
#    'Property, Plant & Equipment Net': '99519000000.0',
#    'Receivables': '14845000000.0',
#    'Retained earnings (deficit)': '21944000000.0',
#    'Short-term debt': '7361000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '25260000000.0',
#    'Tax assets': '1247000000.0',
#    'Total assets': '268312000000.0',
#    'Total current assets': '25187000000.0',
#    'Total current liabilities': '36951000000.0',
#    'Total debt': '72081000000.0',
#    'Total liabilities': '166323000000.0',
#    'Total non-current assets': '243125000000.0',
#    'Total non-current liabilities': '129372000000.0',
#    'Total shareholders equity': '101564000000.0',
#    'date': '2009-12-31'},
#   {'Cash and cash equivalents': '6167000000.0',
#    'Cash and short-term investments': '6167000000.0',
#    'Deferred revenue': '4036000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '133143000000.0',
#    'Inventories': '0.0',
#    'Investments': '2813000000.0',
#    'Long-term debt': '65909000000.0',
#    'Long-term investments': '2813000000.0',
#    'Net Debt': '66497000000.0',
#    'Other Assets': '4958000000.0',
#    'Other Liabilities': '8420000000.0',
#    'Other comprehensive income': '-16161000000.0',
#    'Payables': '18093000000.0',
#    'Property, Plant & Equipment Net': '98321000000.0',
#    'Receivables': '14796000000.0',
#    'Retained earnings (deficit)': '38841000000.0',
#    'Short-term debt': '6755000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '24244000000.0',
#    'Tax assets': '991000000.0',
#    'Total assets': '266568000000.0',
#    'Total current assets': '240647000000.0',
#    'Total current liabilities': '33268000000.0',
#    'Total debt': '72664000000.0',
#    'Total liabilities': '166567000000.0',
#    'Total non-current assets': '133299000000.0',
#    'Total non-current liabilities': '133299000000.0',
#    'Total shareholders equity': '99573000000.0',
#    'date': '2009-09-30'},
#   {'Cash and cash equivalents': '7348000000.0',
#    'Cash and short-term investments': '7348000000.0',
#    'Deferred revenue': '3932000000.0',
#    'Deposit Liabilities': '0.0',
#    'Goodwill and Intangible Assets': '133820000000.0',
#    'Inventories': '0.0',
#    'Investments': '2749000000.0',
#    'Long-term debt': '66565000000.0',
#    'Long-term investments': '2749000000.0',
#    'Net Debt': '69372000000.0',
#    'Other Assets': '4746000000.0',
#    'Other Liabilities': '8018000000.0',
#    'Other comprehensive income': '-16308000000.0',
#    'Payables': '18046000000.0',
#    'Property, Plant & Equipment Net': '98229000000.0',
#    'Receivables': '14846000000.0',
#    'Retained earnings (deficit)': '38069000000.0',
#    'Short-term debt': '10155000000.0',
#    'Short-term investments': '0.0',
#    'Tax Liabilities': '22021000000.0',
#    'Tax assets': '964000000.0',
#    'Total assets': '267918000000.0',
#    'Total current assets': '240978000000.0',
#    'Total current liabilities': '36219000000.0',
#    'Total debt': '76720000000.0',
#    'Total liabilities': '168906000000.0',
#    'Total non-current assets': '132687000000.0',
#    'Total non-current liabilities': '132687000000.0',
#    'Total shareholders equity': '98609000000.0',
#    'date': '2009-06-30'}],
#  'symbol': 'T'}

# %%
# Shareholder Equity
equity_now = float(balance_sheet['financials'][0]['Total shareholders equity'])
print(f'Total Shareholder Equity Today = {equity_now}')

equity_lastyr = float(balance_sheet['financials'][4]['Total shareholders equity'])
print(f'Total Shareholder Equity Last Year = {equity_lastyr}')

average_equity = (equity_now + equity_lastyr)/2
print(f'Average Equity = {average_equity}')
# Out:
# Total Shareholder Equity Today = 194327000000.0
# Total Shareholder Equity Last Year = 184971000000.0
# Average Equity = 189649000000.0

# %%
# Calculate Return On Equity
ROE = net_income/average_equity
print(f'ROE for {stock}= {ROE}')
# Out:
# ROE for t= 0.019509725861987143

# %%
stocks = ['t', 'nrz', 'aapl',]

# %%
# Return On Equity Function
def getROE(stock):
  income_statement = r.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{stock}?period=quarter")
  data = income_statement.json()
  net_income = float(data['financials'][0]['Net Income Com'])
  balance_sheet = r.get(f"https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{stock}?period=quarter")
  balance_sheet = balance_sheet.json()
  equity_now = float(balance_sheet['financials'][0]['Total shareholders equity'])
  equity_lastyr = float(balance_sheet['financials'][4]['Total shareholders equity'])
  average_equity = (equity_now + equity_lastyr)/2
  ROE = net_income/average_equity
  print(f'ROE for {stock}= {ROE}')

# %%
# Calculate REO for list of stocks
[getROE(i) for i in stocks]
# Out:
# ROE for t= 0.019509725861987143
# ROE for nrz= 0.03476052263677193
# ROE for aapl= 0.21440245295844723
# [None, None, None]
